# %%
# Generic inputs for most ML tasks
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LinearRegression
from sklearn.linear_model import Ridge
from sklearn.linear_model import Lasso
from sklearn import tree
import graphviz
from sklearn.tree import DecisionTreeClassifier
from sklearn.tree import DecisionTreeRegressor
from sklearn.ensemble import BaggingRegressor
from sklearn.ensemble import RandomForestRegressor
from sklearn.ensemble import GradientBoostingRegressor
from sklearn.ensemble import RandomForestClassifier

pd.options.display.float_format = '{:,.2f}'.format

# setup interactive notebook mode
from IPython.core.interactiveshell import InteractiveShell
InteractiveShell.ast_node_interactivity = "all"

from IPython.display import display, HTML

# %%
# fetch data 
airline_data = pd.read_csv('airline_dataset_2022_23.csv')
airline_data.head()
# Out:
#   Carrier Code Date (MM/DD/YYYY)  Flight Number Tail Number Origin Airport  \
# 0           9E            1/1/23           5190      N325PQ            JFK
# 1           9E            1/2/22           5531      N678CA            JFK
# 2           9E            1/2/23           5190      N195PQ            JFK
# 3           9E            1/3/22           5531      N602LR            JFK
# 4           9E            1/3/23           5190      N303PQ            JFK
#
#   Scheduled Arrival Time Actual Arrival Time  \
# 0               22:41:00               22:13
# 1               14:12:00               17:12
# 2               22:41:00               22:46
# 3               14:12:00               14:24
# 4               22:41:00               22:23
#
#    Scheduled Elapsed Time (Minutes)  Actual Elapsed Time (Minutes)  \
# 0                                91                             68
# 1                                77                             84
# 2                                91                             77
# 3                                77                             81
# 4                                91                             78
#
#    Arrival Delay (Minutes)  ...      ts_des  uv_des  vis_des  \
# 0                      -28  ...  1672631100    0.00       11
# 1                      180  ...  1641150900    0.50       12
# 2                        5  ...  1672717500    0.00       16
# 3                       12  ...  1641237300    1.10       16
# 4                      -18  ...  1672803900    0.00        4
#
#    weather.icon_des  weather.description_des  weather.code_des  wind_dir_des  \
# 0               804                     c04n   Overcast clouds           285
# 1              c04d          Overcast clouds               804           305
# 2               804                     c04n   Overcast clouds            75
# 3              c03d            Broken clouds               803           320
# 4               804                     c04n   Overcast clouds            70
#
#   wind_gust_spd_des wind_spd_des Location_des
# 0              3.40         1.50          SYR
# 1             10.90         4.97          SYR
# 2              2.40         0.50          SYR
# 3              8.40         2.60          SYR
# 4              4.00         2.10          SYR
#
# [5 rows x 90 columns]

# %%
airline_data.shape
# Out:
# (5623, 90)

# %%
pd.set_option('display.max_columns', None)
airline_data.columns
# Out:
# Index(['Carrier Code', 'Date (MM/DD/YYYY)', 'Flight Number', 'Tail Number',
#        'Origin Airport', 'Scheduled Arrival Time', 'Actual Arrival Time',
#        'Scheduled Elapsed Time (Minutes)', 'Actual Elapsed Time (Minutes)',
#        'Arrival Delay (Minutes)', 'Wheels-on Time', 'Taxi-In time (Minutes)',
#        'Delay Carrier (Minutes)_x', 'Delay Weather (Minutes)_x',
#        'Delay National Aviation System (Minutes)_x',
#        'Delay Security (Minutes)_x', 'Delay Late Aircraft Arrival (Minutes)_x',
#        'Destination Airport', 'Scheduled departure time',
#        'Actual departure time', 'Scheduled elapsed time (Minutes)',
#        'Actual elapsed time (Minutes)', 'Departure delay (Minutes)',
#        'Wheels-off time', 'Taxi-Out time (Minutes)',
#        'Delay Carrier (Minutes)_y', 'Delay Weather (Minutes)_y',
#        'Delay National Aviation System (Minutes)_y',
#        'Delay Security (Minutes)_y', 'Delay Late Aircraft Arrival (Minutes)_y',
#        'Arrival_time', 'departure_time', 'app_temp', 'azimuth', 'clouds',
#        'dewpt', 'dhi', 'dni', 'elev_angle', 'ghi', 'pod', 'precip_rate',
#        'pres', 'revision_status', 'rh', 'slp', 'snow_rate', 'solar_rad',
#        'temp', 'timestamp_local', 'timestamp_utc', 'ts', 'uv', 'vis',
#        'weather.code', 'weather.icon', 'weather.description', 'wind_dir',
#        'wind_gust_spd', 'wind_spd', 'Location', 'app_temp_des', 'azimuth_des',
#        'clouds_des', 'dewpt_des', 'dhi_des', 'dni_des', 'elev_angle_des',
#        'ghi_des', 'pod_des', 'precip_rate_des', 'pres_des',
#        'revision_status_des', 'rh_des', 'slp_des', 'snow_rate_des',
#        'solar_rad_des', 'temp_des', 'timestamp_local_des', 'timestamp_utc_des',
#        'ts_des', 'uv_des', 'vis_des', 'weather.icon_des',
#        'weather.description_des', 'weather.code_des', 'wind_dir_des',
#        'wind_gust_spd_des', 'wind_spd_des', 'Location_des'],
#       dtype='object')

# %%
#Unique carrier codes in the dataset
OP_CARRIER_unique_values = airline_data['Carrier Code'].unique()
print(OP_CARRIER_unique_values)
# Out:
# ['9E' 'MQ' 'B6' 'WN' 'UA']

# %%
airline_data.isna().sum()
# Out:
# Carrier Code          0
# Date (MM/DD/YYYY)     0
# Flight Number         0
# Tail Number          11
# Origin Airport        0
#                      ..
# weather.code_des      0
# wind_dir_des          0
# wind_gust_spd_des     0
# wind_spd_des          0
# Location_des          0
# Length: 90, dtype: int64

# %%
airline_data.dropna(inplace=True)

# %%
airline_data.isna().sum()
# Out:
# Carrier Code         0
# Date (MM/DD/YYYY)    0
# Flight Number        0
# Tail Number          0
# Origin Airport       0
#                     ..
# weather.code_des     0
# wind_dir_des         0
# wind_gust_spd_des    0
# wind_spd_des         0
# Location_des         0
# Length: 90, dtype: int64

# %%
airline_data['Arrival Delay (Minutes)']=airline_data['Arrival Delay (Minutes)'].astype(np.int64)

# %%
airline_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 5612 entries, 0 to 5622
# Data columns (total 90 columns):
#  #   Column                                      Non-Null Count  Dtype
# ---  ------                                      --------------  -----
#  0   Carrier Code                                5612 non-null   object
#  1   Date (MM/DD/YYYY)                           5612 non-null   object
#  2   Flight Number                               5612 non-null   int64
#  3   Tail Number                                 5612 non-null   object
#  4   Origin Airport                              5612 non-null   object
#  5   Scheduled Arrival Time                      5612 non-null   object
#  6   Actual Arrival Time                         5612 non-null   object
#  7   Scheduled Elapsed Time (Minutes)            5612 non-null   int64
#  8   Actual Elapsed Time (Minutes)               5612 non-null   int64
#  9   Arrival Delay (Minutes)                     5612 non-null   int64
#  10  Wheels-on Time                              5612 non-null   object
#  11  Taxi-In time (Minutes)                      5612 non-null   int64
#  12  Delay Carrier (Minutes)_x                   5612 non-null   int64
#  13  Delay Weather (Minutes)_x                   5612 non-null   int64
#  14  Delay National Aviation System (Minutes)_x  5612 non-null   int64
#  15  Delay Security (Minutes)_x                  5612 non-null   int64
#  16  Delay Late Aircraft Arrival (Minutes)_x     5612 non-null   int64
#  17  Destination Airport                         5612 non-null   object
#  18  Scheduled departure time                    5612 non-null   object
#  19  Actual departure time                       5612 non-null   object
#  20  Scheduled elapsed time (Minutes)            5612 non-null   int64
#  21  Actual elapsed time (Minutes)               5612 non-null   int64
#  22  Departure delay (Minutes)                   5612 non-null   int64
#  23  Wheels-off time                             5612 non-null   object
#  24  Taxi-Out time (Minutes)                     5612 non-null   int64
#  25  Delay Carrier (Minutes)_y                   5612 non-null   int64
#  26  Delay Weather (Minutes)_y                   5612 non-null   int64
#  27  Delay National Aviation System (Minutes)_y  5612 non-null   int64
#  28  Delay Security (Minutes)_y                  5612 non-null   int64
#  29  Delay Late Aircraft Arrival (Minutes)_y     5612 non-null   int64
#  30  Arrival_time                                5612 non-null   object
#  31  departure_time                              5612 non-null   object
#  32  app_temp                                    5612 non-null   float64
#  33  azimuth                                     5612 non-null   float64
#  34  clouds                                      5612 non-null   int64
#  35  dewpt                                       5612 non-null   float64
#  36  dhi                                         5612 non-null   int64
#  37  dni                                         5612 non-null   int64
#  38  elev_angle                                  5612 non-null   float64
#  39  ghi                                         5612 non-null   int64
#  40  pod                                         5612 non-null   object
#  41  precip_rate                                 5612 non-null   float64
#  42  pres                                        5612 non-null   int64
#  43  revision_status                             5612 non-null   object
#  44  rh                                          5612 non-null   int64
#  45  slp                                         5612 non-null   int64
#  46  snow_rate                                   5612 non-null   float64
#  47  solar_rad                                   5612 non-null   int64
#  48  temp                                        5612 non-null   float64
#  49  timestamp_local                             5612 non-null   object
#  50  timestamp_utc                               5612 non-null   object
#  51  ts                                          5612 non-null   int64
#  52  uv                                          5612 non-null   float64
#  53  vis                                         5612 non-null   int64
#  54  weather.code                                5612 non-null   object
#  55  weather.icon                                5612 non-null   object
#  56  weather.description                         5612 non-null   object
#  57  wind_dir                                    5612 non-null   int64
#  58  wind_gust_spd                               5612 non-null   float64
#  59  wind_spd                                    5612 non-null   float64
#  60  Location                                    5612 non-null   object
#  61  app_temp_des                                5612 non-null   float64
#  62  azimuth_des                                 5612 non-null   float64
#  63  clouds_des                                  5612 non-null   int64
#  64  dewpt_des                                   5612 non-null   float64
#  65  dhi_des                                     5612 non-null   int64
#  66  dni_des                                     5612 non-null   int64
#  67  elev_angle_des                              5612 non-null   float64
#  68  ghi_des                                     5612 non-null   int64
#  69  pod_des                                     5612 non-null   object
#  70  precip_rate_des                             5612 non-null   float64
#  71  pres_des                                    5612 non-null   int64
#  72  revision_status_des                         5612 non-null   object
#  73  rh_des                                      5612 non-null   int64
#  74  slp_des                                     5612 non-null   int64
#  75  snow_rate_des                               5612 non-null   float64
#  76  solar_rad_des                               5612 non-null   int64
#  77  temp_des                                    5612 non-null   float64
#  78  timestamp_local_des                         5612 non-null   object
#  79  timestamp_utc_des                           5612 non-null   object
#  80  ts_des                                      5612 non-null   int64
#  81  uv_des                                      5612 non-null   float64
#  82  vis_des                                     5612 non-null   int64
#  83  weather.icon_des                            5612 non-null   object
#  84  weather.description_des                     5612 non-null   object
#  85  weather.code_des                            5612 non-null   object
#  86  wind_dir_des                                5612 non-null   int64
#  87  wind_gust_spd_des                           5612 non-null   float64
#  88  wind_spd_des                                5612 non-null   float64
#  89  Location_des                                5612 non-null   object
# dtypes: float64(20), int64(41), object(29)
# memory usage: 3.9+ MB

# %%
#function to set status of flight based on Arrival Delay
def set_dependent_variable(time):
    if time<-5:
        return 'Early'
    elif (time>=-5 and time<=5):
        return 'On-time'
    else:
        return 'Late'

# %%
airline_data['Status']=airline_data['Arrival Delay (Minutes)'].apply(set_dependent_variable)

# %%
airline_data.columns
# Out:
# Index(['Carrier Code', 'Date (MM/DD/YYYY)', 'Flight Number', 'Tail Number',
#        'Origin Airport', 'Scheduled Arrival Time', 'Actual Arrival Time',
#        'Scheduled Elapsed Time (Minutes)', 'Actual Elapsed Time (Minutes)',
#        'Arrival Delay (Minutes)', 'Wheels-on Time', 'Taxi-In time (Minutes)',
#        'Delay Carrier (Minutes)_x', 'Delay Weather (Minutes)_x',
#        'Delay National Aviation System (Minutes)_x',
#        'Delay Security (Minutes)_x', 'Delay Late Aircraft Arrival (Minutes)_x',
#        'Destination Airport', 'Scheduled departure time',
#        'Actual departure time', 'Scheduled elapsed time (Minutes)',
#        'Actual elapsed time (Minutes)', 'Departure delay (Minutes)',
#        'Wheels-off time', 'Taxi-Out time (Minutes)',
#        'Delay Carrier (Minutes)_y', 'Delay Weather (Minutes)_y',
#        'Delay National Aviation System (Minutes)_y',
#        'Delay Security (Minutes)_y', 'Delay Late Aircraft Arrival (Minutes)_y',
#        'Arrival_time', 'departure_time', 'app_temp', 'azimuth', 'clouds',
#        'dewpt', 'dhi', 'dni', 'elev_angle', 'ghi', 'pod', 'precip_rate',
#        'pres', 'revision_status', 'rh', 'slp', 'snow_rate', 'solar_rad',
#        'temp', 'timestamp_local', 'timestamp_utc', 'ts', 'uv', 'vis',
#        'weather.code', 'weather.icon', 'weather.description', 'wind_dir',
#        'wind_gust_spd', 'wind_spd', 'Location', 'app_temp_des', 'azimuth_des',
#        'clouds_des', 'dewpt_des', 'dhi_des', 'dni_des', 'elev_angle_des',
#        'ghi_des', 'pod_des', 'precip_rate_des', 'pres_des',
#        'revision_status_des', 'rh_des', 'slp_des', 'snow_rate_des',
#        'solar_rad_des', 'temp_des', 'timestamp_local_des', 'timestamp_utc_des',
#        'ts_des', 'uv_des', 'vis_des', 'weather.icon_des',
#        'weather.description_des', 'weather.code_des', 'wind_dir_des',
#        'wind_gust_spd_des', 'wind_spd_des', 'Location_des', 'Status'],
#       dtype='object')

# %%
airline_data.isna().sum()
# Out:
# Carrier Code         0
# Date (MM/DD/YYYY)    0
# Flight Number        0
# Tail Number          0
# Origin Airport       0
#                     ..
# wind_dir_des         0
# wind_gust_spd_des    0
# wind_spd_des         0
# Location_des         0
# Status               0
# Length: 91, dtype: int64

# %%
airline_data.columns
# Out:
# Index(['Carrier Code', 'Date (MM/DD/YYYY)', 'Flight Number', 'Tail Number',
#        'Origin Airport', 'Scheduled Arrival Time', 'Actual Arrival Time',
#        'Scheduled Elapsed Time (Minutes)', 'Actual Elapsed Time (Minutes)',
#        'Arrival Delay (Minutes)', 'Wheels-on Time', 'Taxi-In time (Minutes)',
#        'Delay Carrier (Minutes)_x', 'Delay Weather (Minutes)_x',
#        'Delay National Aviation System (Minutes)_x',
#        'Delay Security (Minutes)_x', 'Delay Late Aircraft Arrival (Minutes)_x',
#        'Destination Airport', 'Scheduled departure time',
#        'Actual departure time', 'Scheduled elapsed time (Minutes)',
#        'Actual elapsed time (Minutes)', 'Departure delay (Minutes)',
#        'Wheels-off time', 'Taxi-Out time (Minutes)',
#        'Delay Carrier (Minutes)_y', 'Delay Weather (Minutes)_y',
#        'Delay National Aviation System (Minutes)_y',
#        'Delay Security (Minutes)_y', 'Delay Late Aircraft Arrival (Minutes)_y',
#        'Arrival_time', 'departure_time', 'app_temp', 'azimuth', 'clouds',
#        'dewpt', 'dhi', 'dni', 'elev_angle', 'ghi', 'pod', 'precip_rate',
#        'pres', 'revision_status', 'rh', 'slp', 'snow_rate', 'solar_rad',
#        'temp', 'timestamp_local', 'timestamp_utc', 'ts', 'uv', 'vis',
#        'weather.code', 'weather.icon', 'weather.description', 'wind_dir',
#        'wind_gust_spd', 'wind_spd', 'Location', 'app_temp_des', 'azimuth_des',
#        'clouds_des', 'dewpt_des', 'dhi_des', 'dni_des', 'elev_angle_des',
#        'ghi_des', 'pod_des', 'precip_rate_des', 'pres_des',
#        'revision_status_des', 'rh_des', 'slp_des', 'snow_rate_des',
#        'solar_rad_des', 'temp_des', 'timestamp_local_des', 'timestamp_utc_des',
#        'ts_des', 'uv_des', 'vis_des', 'weather.icon_des',
#        'weather.description_des', 'weather.code_des', 'wind_dir_des',
#        'wind_gust_spd_des', 'wind_spd_des', 'Location_des', 'Status'],
#       dtype='object')

# %%
airline_data.drop(columns=['Tail Number','Actual Arrival Time',
       'Scheduled Elapsed Time (Minutes)', 'Actual Elapsed Time (Minutes)',
       'Arrival Delay (Minutes)', 'Wheels-on Time', 'Taxi-In time (Minutes)',
       'Delay Carrier (Minutes)_x', 'Delay Weather (Minutes)_x',
       'Delay National Aviation System (Minutes)_x',
       'Delay Security (Minutes)_x', 'Delay Late Aircraft Arrival (Minutes)_x', 'Actual departure time', 'Scheduled elapsed time (Minutes)',
       'Actual elapsed time (Minutes)', 'Departure delay (Minutes)',
       'Wheels-off time', 'Taxi-Out time (Minutes)',
       'Delay Carrier (Minutes)_y', 'Delay Weather (Minutes)_y',
       'Delay National Aviation System (Minutes)_y',
       'Delay Security (Minutes)_y', 'Delay Late Aircraft Arrival (Minutes)_y', 'app_temp', 'azimuth', 'clouds',
       'dewpt', 'dhi', 'dni', 'elev_angle', 'ghi', 'pod', 'precip_rate',
       'pres', 'revision_status', 'rh', 'slp', 'snow_rate', 'solar_rad',
       'temp', 'timestamp_local', 'timestamp_utc', 'ts', 'uv', 'vis',
       'weather.code', 'weather.icon', 'weather.description', 'wind_dir',
       'wind_gust_spd', 'wind_spd', 'Location'],inplace=True)
airline_data.head()
# Out:
#   Carrier Code Date (MM/DD/YYYY)  Flight Number Origin Airport  \
# 0           9E            1/1/23           5190            JFK
# 1           9E            1/2/22           5531            JFK
# 2           9E            1/2/23           5190            JFK
# 3           9E            1/3/22           5531            JFK
# 4           9E            1/3/23           5190            JFK
#
#   Scheduled Arrival Time Destination Airport Scheduled departure time  \
# 0               22:41:00                 SYR                 21:10:00
# 1               14:12:00                 SYR                 12:55:00
# 2               22:41:00                 SYR                 21:10:00
# 3               14:12:00                 SYR                 12:55:00
# 4               22:41:00                 SYR                 21:10:00
#
#    Arrival_time departure_time  app_temp_des  azimuth_des  clouds_des  \
# 0  1/1/23 22:45   1/1/23 21:15          2.70       314.00         100
# 1  1/2/22 14:15   1/2/22 13:00        -11.10       210.40         100
# 2  1/2/23 22:45   1/2/23 21:15          5.10       313.90         100
# 3  1/3/22 14:15   1/3/22 13:00        -11.50       210.30          43
# 4  1/3/23 22:45   1/3/23 21:15          3.30       313.80         100
#
#    dewpt_des  dhi_des  dni_des  elev_angle_des  ghi_des pod_des  \
# 0       2.10        0        0          -63.30        0       n
# 1      -6.20       75      657           17.60      268       d
# 2       0.60        0        0          -63.10        0       n
# 3     -15.20       75      659           17.80      271       d
# 4       3.80        0        0          -63.00        0       n
#
#    precip_rate_des  pres_des revision_status_des  rh_des  slp_des  \
# 0             0.00      1000               final      88     1015
# 1             0.00       996               final      91     1011
# 2             0.00      1005               final      77     1020
# 3             0.00      1009               final      52     1025
# 4             0.00       991               final      92     1006
#
#    snow_rate_des  solar_rad_des  temp_des timestamp_local_des  \
# 0           0.00              0      3.90        1/1/23 22:45
# 1           0.00            102     -5.00        1/2/22 14:15
# 2           0.00              0      4.20        1/2/23 22:45
# 3           0.00            257     -7.10        1/3/22 14:15
# 4           0.00              0      5.00        1/3/23 22:45
#
#   timestamp_utc_des      ts_des  uv_des  vis_des weather.icon_des  \
# 0       1/2/23 3:45  1672631100    0.00       11              804
# 1      1/2/22 19:15  1641150900    0.50       12             c04d
# 2       1/3/23 3:45  1672717500    0.00       16              804
# 3      1/3/22 19:15  1641237300    1.10       16             c03d
# 4       1/4/23 3:45  1672803900    0.00        4              804
#
#   weather.description_des weather.code_des  wind_dir_des  wind_gust_spd_des  \
# 0                    c04n  Overcast clouds           285               3.40
# 1         Overcast clouds              804           305              10.90
# 2                    c04n  Overcast clouds            75               2.40
# 3           Broken clouds              803           320               8.40
# 4                    c04n  Overcast clouds            70               4.00
#
#    wind_spd_des Location_des   Status
# 0          1.50          SYR    Early
# 1          4.97          SYR     Late
# 2          0.50          SYR  On-time
# 3          2.60          SYR     Late
# 4          2.10          SYR    Early

# %%
airline_data.columns
# Out:
# Index(['Carrier Code', 'Date (MM/DD/YYYY)', 'Flight Number', 'Origin Airport',
#        'Scheduled Arrival Time', 'Destination Airport',
#        'Scheduled departure time', 'Arrival_time', 'departure_time',
#        'app_temp_des', 'azimuth_des', 'clouds_des', 'dewpt_des', 'dhi_des',
#        'dni_des', 'elev_angle_des', 'ghi_des', 'pod_des', 'precip_rate_des',
#        'pres_des', 'revision_status_des', 'rh_des', 'slp_des', 'snow_rate_des',
#        'solar_rad_des', 'temp_des', 'timestamp_local_des', 'timestamp_utc_des',
#        'ts_des', 'uv_des', 'vis_des', 'weather.icon_des',
#        'weather.description_des', 'weather.code_des', 'wind_dir_des',
#        'wind_gust_spd_des', 'wind_spd_des', 'Location_des', 'Status'],
#       dtype='object')

# %%
len(airline_data.columns)
# Out:
# 39

# %%
airline_data.drop(columns=['Arrival_time', 'departure_time',
                            'timestamp_local_des', 'timestamp_utc_des', 'Location_des',
                            'elev_angle_des', 'ts_des', 'app_temp_des',
                          'azimuth_des', 'dhi_des', 'dni_des', 'elev_angle_des', 
                           'ghi_des', 'pod_des', 'revision_status_des', 'weather.code_des',
                           'weather.icon_des', 'weather.description_des', 'solar_rad_des',
                           'vis_des'], 
                  inplace=True)
airline_data.head()
# Out:
#   Carrier Code Date (MM/DD/YYYY)  Flight Number Origin Airport  \
# 0           9E            1/1/23           5190            JFK
# 1           9E            1/2/22           5531            JFK
# 2           9E            1/2/23           5190            JFK
# 3           9E            1/3/22           5531            JFK
# 4           9E            1/3/23           5190            JFK
#
#   Scheduled Arrival Time Destination Airport Scheduled departure time  \
# 0               22:41:00                 SYR                 21:10:00
# 1               14:12:00                 SYR                 12:55:00
# 2               22:41:00                 SYR                 21:10:00
# 3               14:12:00                 SYR                 12:55:00
# 4               22:41:00                 SYR                 21:10:00
#
#    clouds_des  dewpt_des  precip_rate_des  pres_des  rh_des  slp_des  \
# 0         100       2.10             0.00      1000      88     1015
# 1         100      -6.20             0.00       996      91     1011
# 2         100       0.60             0.00      1005      77     1020
# 3          43     -15.20             0.00      1009      52     1025
# 4         100       3.80             0.00       991      92     1006
#
#    snow_rate_des  temp_des  uv_des  wind_dir_des  wind_gust_spd_des  \
# 0           0.00      3.90    0.00           285               3.40
# 1           0.00     -5.00    0.50           305              10.90
# 2           0.00      4.20    0.00            75               2.40
# 3           0.00     -7.10    1.10           320               8.40
# 4           0.00      5.00    0.00            70               4.00
#
#    wind_spd_des   Status
# 0          1.50    Early
# 1          4.97     Late
# 2          0.50  On-time
# 3          2.60     Late
# 4          2.10    Early

# %%
import plotly
plotly.offline.init_notebook_mode(connected=True)
from plotly.graph_objs import *
from plotly import tools
import plotly.graph_objects as go
import seaborn as sns
# Out:
#         <script type="text/javascript">
#         window.PlotlyConfig = {MathJaxConfig: 'local'};
#         if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}
#         if (typeof require !== 'undefined') {
#         require.undef("plotly");
#         requirejs.config({
#             paths: {
#                 'plotly': ['https://cdn.plot.ly/plotly-2.12.1.min']
#             }
#         });
#         require(['plotly'], function(Plotly) {
#             window._Plotly = Plotly;
#         });
#         }
#         </script>

# %%
numeric_columns = airline_data.select_dtypes(include=['float64', 'int64'])

correl = numeric_columns.corr()

trace = go.Heatmap(z=correl.values,
                  x=correl.index.values,
                  y=correl.columns.values)
data=[trace]
plotly.offline.iplot(data, filename='Airline data heatmap')
# Out:
# <div>                            <div id="5d06c039-326b-4a15-8d2d-54e29116ec1b" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("5d06c039-326b-4a15-8d2d-54e29116ec1b")) {                    Plotly.newPlot(                        "5d06c039-326b-4a15-8d2d-54e29116ec1b",                        [{"x":["Flight Number","clouds_des","dewpt_des","precip_rate_des","pres_des","rh_des","slp_des","snow_rate_des","temp_des","uv_des","wind_dir_des","wind_gust_spd_des","wind_spd_des"],"y":["Flight Number","clouds_des","dewpt_des","precip_rate_des","pres_des","rh_des","slp_des","snow_rate_des","temp_des","uv_des","wind_dir_des","wind_gust_spd_des","wind_spd_des"],"z":[[1.0,-0.02039508043655035,0.09344429996042881,0.012606637763430528,-0.000778374284295876,-0.0009476696680027825,-0.004471446484465617,-0.012742166064976095,0.09203693450576171,0.10831663309038925,-0.00040485017454058457,-0.002437018935379966,-0.019517318875689953],[-0.02039508043655035,1.0,-0.013350129138237058,0.08899643893621738,-0.31042020286653776,0.30632627458416695,-0.3008455424522485,0.08788632450531869,-0.1644796716118512,-0.26652973826500265,-0.030817428928707778,0.2606383116720426,0.21202250012687338],[0.09344429996042881,-0.013350129138237058,1.0,0.08272502140702465,-0.3435863608762126,0.21190222128113104,-0.3753171566738155,-0.09569377824376134,0.8778661851531345,0.11104466905326518,-0.08021516343946238,-0.23177442566605735,-0.23170672587590022],[0.012606637763430528,0.08899643893621738,0.08272502140702465,1.0,-0.09169998092653793,0.12140090212871611,-0.09331031693772213,0.08270801999305603,0.02892319196393782,-0.02327885134253086,-0.03963886121187905,0.04238711953164152,0.010470352667832429],[-0.000778374284295876,-0.31042020286653776,-0.3435863608762126,-0.09169998092653793,1.0,-0.23749449014315574,0.9940678729017617,-0.036096064302578355,-0.23279921441488843,0.042156506319686655,-0.008586413392033216,-0.2745942242649767,-0.24382725602221014],[-0.0009476696680027825,0.30632627458416695,0.21190222128113104,0.12140090212871611,-0.23749449014315574,1.0,-0.23145996025495313,0.13506232727241704,-0.2719409350737018,-0.49100601778180475,-0.09777538363207239,-0.15765504317285817,-0.22114080161648159],[-0.004471446484465617,-0.3008455424522485,-0.3753171566738155,-0.09331031693772213,0.9940678729017617,-0.23145996025495313,1.0,-0.039851089839524484,-0.2669688048713987,0.03301336211827855,-0.006302838060860306,-0.26556879449333115,-0.23637915056309164],[-0.012742166064976095,0.08788632450531869,-0.09569377824376134,0.08270801999305603,-0.036096064302578355,0.13506232727241704,-0.039851089839524484,1.0,-0.1462880558779736,-0.042217130474267596,-0.07516774077489631,0.0509064265360648,0.0548973705812462],[0.09203693450576171,-0.1644796716118512,0.8778661851531345,0.02892319196393782,-0.23279921441488843,-0.2719409350737018,-0.2669688048713987,-0.1462880558779736,1.0,0.3669200719458077,-0.0348389427139928,-0.15048675380146395,-0.1207616668817638],[0.10831663309038925,-0.26652973826500265,0.11104466905326518,-0.02327885134253086,0.042156506319686655,-0.49100601778180475,0.03301336211827855,-0.042217130474267596,0.3669200719458077,1.0,0.10802340166511142,0.18320177950111502,0.1645231244692892],[-0.00040485017454058457,-0.030817428928707778,-0.08021516343946238,-0.03963886121187905,-0.008586413392033216,-0.09777538363207239,-0.006302838060860306,-0.07516774077489631,-0.0348389427139928,0.10802340166511142,1.0,0.1522551273876367,0.2499253086429091],[-0.002437018935379966,0.2606383116720426,-0.23177442566605735,0.04238711953164152,-0.2745942242649767,-0.15765504317285817,-0.26556879449333115,0.0509064265360648,-0.15048675380146395,0.18320177950111502,0.1522551273876367,1.0,0.8023707596318683],[-0.019517318875689953,0.21202250012687338,-0.231706725875 ...

# %%
len(airline_data.columns)
# Out:
# 20

# %%
airline_data.head()
# Out:
#   Carrier Code Date (MM/DD/YYYY)  Flight Number Origin Airport  \
# 0           9E            1/1/23           5190            JFK
# 1           9E            1/2/22           5531            JFK
# 2           9E            1/2/23           5190            JFK
# 3           9E            1/3/22           5531            JFK
# 4           9E            1/3/23           5190            JFK
#
#   Scheduled Arrival Time Destination Airport Scheduled departure time  \
# 0               22:41:00                 SYR                 21:10:00
# 1               14:12:00                 SYR                 12:55:00
# 2               22:41:00                 SYR                 21:10:00
# 3               14:12:00                 SYR                 12:55:00
# 4               22:41:00                 SYR                 21:10:00
#
#    clouds_des  dewpt_des  precip_rate_des  pres_des  rh_des  slp_des  \
# 0         100       2.10             0.00      1000      88     1015
# 1         100      -6.20             0.00       996      91     1011
# 2         100       0.60             0.00      1005      77     1020
# 3          43     -15.20             0.00      1009      52     1025
# 4         100       3.80             0.00       991      92     1006
#
#    snow_rate_des  temp_des  uv_des  wind_dir_des  wind_gust_spd_des  \
# 0           0.00      3.90    0.00           285               3.40
# 1           0.00     -5.00    0.50           305              10.90
# 2           0.00      4.20    0.00            75               2.40
# 3           0.00     -7.10    1.10           320               8.40
# 4           0.00      5.00    0.00            70               4.00
#
#    wind_spd_des   Status
# 0          1.50    Early
# 1          4.97     Late
# 2          0.50  On-time
# 3          2.60     Late
# 4          2.10    Early

# %%
# Sort the dataset based on "Carrier Code" and "Date (MM/DD/YYYY)"
airline_data.sort_values(by=["Carrier Code", "Date (MM/DD/YYYY)", "Scheduled Arrival Time"], inplace=True)

# Add a new column to store the status of the previous flight
airline_data['Previous Flight Status'] = airline_data.groupby(['Carrier Code', 'Date (MM/DD/YYYY)'])['Status'].shift(1)

# Handle the first flight within each group
first_flight_mask = airline_data['Previous Flight Status'].isna()
airline_data.loc[first_flight_mask, 'Previous Flight Status'] = 'Unknown'  # Replace "N/A" with "Unknown"

# Print the updated dataset
airline_data.head()
# Out:
#    Carrier Code Date (MM/DD/YYYY)  Flight Number Origin Airport  \
# 0            9E            1/1/23           5190            JFK
# 21           9E           1/10/22           5446            JFK
# 24           9E           1/10/23           5350            JFK
# 23           9E           1/10/23           5224            JFK
# 22           9E           1/10/23           5009            JFK
#
#    Scheduled Arrival Time Destination Airport Scheduled departure time  \
# 0                22:41:00                 SYR                 21:10:00
# 21               13:45:00                 SYR                 12:30:00
# 24               11:15:00                 SYR                  9:50:00
# 23               18:01:00                 SYR                 16:35:00
# 22               23:54:00                 SYR                 22:30:00
#
#     clouds_des  dewpt_des  precip_rate_des  pres_des  rh_des  slp_des  \
# 0          100       2.10             0.00      1000      88     1015
# 21          78     -13.70             0.00      1003      52     1018
# 24         100      -5.00             0.00      1002      72     1018
# 23         100      -7.90             0.00      1004      68     1019
# 22          25     -10.00             0.00      1006      77     1021
#
#     snow_rate_des  temp_des  uv_des  wind_dir_des  wind_gust_spd_des  \
# 0            0.00      3.90    0.00           285               3.40
# 21           0.00     -5.40    0.90           240              14.80
# 24           0.00     -0.60    0.60           340               7.00
# 23           0.00     -2.80    0.00           310               3.60
# 22           0.00     -6.70    0.00           300               2.10
#
#     wind_spd_des   Status Previous Flight Status
# 0           1.50    Early                Unknown
# 21         11.30  On-time                Unknown
# 24          3.10    Early                Unknown
# 23          3.60    Early                  Early
# 22          2.10  On-time                  Early

# %%
airline_data.dtypes
# Out:
# Carrier Code                 object
# Date (MM/DD/YYYY)            object
# Flight Number                 int64
# Origin Airport               object
# Scheduled Arrival Time       object
# Destination Airport          object
# Scheduled departure time     object
# clouds_des                    int64
# dewpt_des                   float64
# precip_rate_des             float64
# pres_des                      int64
# rh_des                        int64
# slp_des                       int64
# snow_rate_des               float64
# temp_des                    float64
# uv_des                      float64
# wind_dir_des                  int64
# wind_gust_spd_des           float64
# wind_spd_des                float64
# Status                       object
# Previous Flight Status       object
# dtype: object

# %%
#spliting the Arrival and Departure times into Hours and minutes for easy understanding to model
airline_data['Scheduled Arrival Hour']= pd.to_datetime(airline_data['Scheduled Arrival Time']).dt.hour
airline_data['Scheduled Arrival Minutes']= pd.to_datetime(airline_data['Scheduled Arrival Time']).dt.minute

airline_data['Scheduled departure Hour']= pd.to_datetime(airline_data['Scheduled departure time']).dt.hour
airline_data['Scheduled departure Minutes']= pd.to_datetime(airline_data['Scheduled departure time']).dt.minute

airline_data
# Out:
# /var/folders/kv/s4mg_r2n60q37wmj416xrvl40000gn/T/ipykernel_79385/59332829.py:2: UserWarning:
#
# Could not infer format, so each element will be parsed individually, falling back to `dateutil`. To ensure parsing is consistent and as-expected, please specify a format.
#
# /var/folders/kv/s4mg_r2n60q37wmj416xrvl40000gn/T/ipykernel_79385/59332829.py:3: UserWarning:
#
# Could not infer format, so each element will be parsed individually, falling back to `dateutil`. To ensure parsing is consistent and as-expected, please specify a format.
#
# /var/folders/kv/s4mg_r2n60q37wmj416xrvl40000gn/T/ipykernel_79385/59332829.py:5: UserWarning:
#
# Could not infer format, so each element will be parsed individually, falling back to `dateutil`. To ensure parsing is consistent and as-expected, please specify a format.
#
# /var/folders/kv/s4mg_r2n60q37wmj416xrvl40000gn/T/ipykernel_79385/59332829.py:6: UserWarning:
#
# Could not infer format, so each element will be parsed individually, falling back to `dateutil`. To ensure parsing is consistent and as-expected, please specify a format.
#      Carrier Code Date (MM/DD/YYYY)  Flight Number Origin Airport  \
# 0              9E            1/1/23           5190            JFK
# 21             9E           1/10/22           5446            JFK
# 24             9E           1/10/23           5350            JFK
# 23             9E           1/10/23           5224            JFK
# 22             9E           1/10/23           5009            JFK
# ...           ...               ...            ...            ...
# 4657           WN           9/23/23           2885            MCO
# 4658           WN           9/24/22           3057            MCO
# 4652           WN            9/3/22           4667            MCO
# 4659           WN           9/30/23           2885            MCO
# 4653           WN            9/9/23           2885            MCO
#
#      Scheduled Arrival Time Destination Airport Scheduled departure time  \
# 0                  22:41:00                 SYR                 21:10:00
# 21                 13:45:00                 SYR                 12:30:00
# 24                 11:15:00                 SYR                  9:50:00
# 23                 18:01:00                 SYR                 16:35:00
# 22                 23:54:00                 SYR                 22:30:00
# ...                     ...                 ...                      ...
# 4657               15:05:00                 SYR                 12:25:00
# 4658               14:55:00                 SYR                 12:15:00
# 4652               13:55:00                 SYR                 11:10:00
# 4659               15:05:00                 SYR                 12:25:00
# 4653               15:05:00                 SYR                 12:25:00
#
#       clouds_des  dewpt_des  precip_rate_des  pres_des  rh_des  slp_des  \
# 0            100       2.10             0.00      1000      88     1015
# 21            78     -13.70             0.00      1003      52     1018
# 24           100      -5.00             0.00      1002      72     1018
# 23           100      -7.90             0.00      1004      68     1019
# 22            25     -10.00             0.00      1006      77     1021
# ...          ...        ...              ...       ...     ...      ...
# 4657          87       8.10             0.00      1008      57     1022
# 4658          87       6.70             0.00      1000      48     1014
# 4652          87      17.10             0.00      1006      54     1020
# 4659          50      13.20             0.00      1007      48     1022
# 4653          87      16.70             0.00      1005      71     1019
#
#       snow_rate_des  temp_des  uv_des  wind_dir_des  wind_gust_spd_des  \
# 0              0.00      3.90    0.00           285               3.40
# 21             0.00     -5.40    0.90           240              14.80
# 24             0.00     -0.60    0.60           340               7.00
# 23             0.00     -2.80    0.00           310               3.60
# 22             0.00     -6.70    0.00           300               2.10
# ...             ...       ...     ...           ...                ...
# 4657           0.00     16.70    1.80            90               7.20
# 4658           0.00     17.80    1.80           270               6.80
# 4652           0.00     27.20    2.80           135               6.80
# 4659           0.00     25.00    2.70           350               6.40
# 4653           0.00     22.20    2.20            70               5.60
#
#       wind_spd_des   Status Previous Flight Status  Scheduled Arrival Hour  \
# 0             1.50    Early                Unknown                      22
# 21           11.30  On-time                Unknown                      13
# 24            3.10    Early                Unknown                      11
# 23            3.60    Early                  Early                      18
# 22            2.10  On-time                  Early                      23
# ...            ...      ...                    ...                     ...
# 4657          3.10    Early                Unknown                      15
# 4658          3.60    Early                Unknown                      14
# 4652          2.80    Early                Unknown                      13
# 4659          3.60  On-time                Unknown                      15
# 4653          1.50    Early                Unknown                      15
#
#       Scheduled Arrival Minutes  Scheduled departure Hour  \
# 0                            41                        21
# 21                           45                        12
# 24                           15                         9
# 23                            1                        16
# 22                           54                        22
# ...                         ...                       ...
# 4657                          5                        12
# 4658                         55                        12
# 4652                         55                        11
# 4659                          5                        12
# 4653                          5                        12
#
#       Scheduled departure Minutes
# 0                              10
# 21                             30
# 24                             50
# 23                             35
# 22                             30
# ...                           ...
# 4657                           25
# 4658                           15
# 4652                           10
# 4659                           25
# 4653                           25
#
# [5612 rows x 25 columns]

# %%
airline_data.drop(columns=['Scheduled Arrival Time'],inplace=True)
airline_data.drop(columns=['Scheduled departure time'],inplace=True)
airline_data.head()
# Out:
#    Carrier Code Date (MM/DD/YYYY)  Flight Number Origin Airport  \
# 0            9E            1/1/23           5190            JFK
# 21           9E           1/10/22           5446            JFK
# 24           9E           1/10/23           5350            JFK
# 23           9E           1/10/23           5224            JFK
# 22           9E           1/10/23           5009            JFK
#
#    Destination Airport  clouds_des  dewpt_des  precip_rate_des  pres_des  \
# 0                  SYR         100       2.10             0.00      1000
# 21                 SYR          78     -13.70             0.00      1003
# 24                 SYR         100      -5.00             0.00      1002
# 23                 SYR         100      -7.90             0.00      1004
# 22                 SYR          25     -10.00             0.00      1006
#
#     rh_des  slp_des  snow_rate_des  temp_des  uv_des  wind_dir_des  \
# 0       88     1015           0.00      3.90    0.00           285
# 21      52     1018           0.00     -5.40    0.90           240
# 24      72     1018           0.00     -0.60    0.60           340
# 23      68     1019           0.00     -2.80    0.00           310
# 22      77     1021           0.00     -6.70    0.00           300
#
#     wind_gust_spd_des  wind_spd_des   Status Previous Flight Status  \
# 0                3.40          1.50    Early                Unknown
# 21              14.80         11.30  On-time                Unknown
# 24               7.00          3.10    Early                Unknown
# 23               3.60          3.60    Early                  Early
# 22               2.10          2.10  On-time                  Early
#
#     Scheduled Arrival Hour  Scheduled Arrival Minutes  \
# 0                       22                         41
# 21                      13                         45
# 24                      11                         15
# 23                      18                          1
# 22                      23                         54
#
#     Scheduled departure Hour  Scheduled departure Minutes
# 0                         21                           10
# 21                        12                           30
# 24                         9                           50
# 23                        16                           35
# 22                        22                           30

# %%
airline_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 5612 entries, 0 to 4653
# Data columns (total 23 columns):
#  #   Column                       Non-Null Count  Dtype
# ---  ------                       --------------  -----
#  0   Carrier Code                 5612 non-null   object
#  1   Date (MM/DD/YYYY)            5612 non-null   object
#  2   Flight Number                5612 non-null   int64
#  3   Origin Airport               5612 non-null   object
#  4   Destination Airport          5612 non-null   object
#  5   clouds_des                   5612 non-null   int64
#  6   dewpt_des                    5612 non-null   float64
#  7   precip_rate_des              5612 non-null   float64
#  8   pres_des                     5612 non-null   int64
#  9   rh_des                       5612 non-null   int64
#  10  slp_des                      5612 non-null   int64
#  11  snow_rate_des                5612 non-null   float64
#  12  temp_des                     5612 non-null   float64
#  13  uv_des                       5612 non-null   float64
#  14  wind_dir_des                 5612 non-null   int64
#  15  wind_gust_spd_des            5612 non-null   float64
#  16  wind_spd_des                 5612 non-null   float64
#  17  Status                       5612 non-null   object
#  18  Previous Flight Status       5612 non-null   object
#  19  Scheduled Arrival Hour       5612 non-null   int32
#  20  Scheduled Arrival Minutes    5612 non-null   int32
#  21  Scheduled departure Hour     5612 non-null   int32
#  22  Scheduled departure Minutes  5612 non-null   int32
# dtypes: float64(7), int32(4), int64(6), object(6)
# memory usage: 964.6+ KB

# %%
airline_data['Date'] = airline_data['Date (MM/DD/YYYY)'].astype('datetime64[ns]')
# Out:
# /var/folders/kv/s4mg_r2n60q37wmj416xrvl40000gn/T/ipykernel_79385/2454959777.py:1: UserWarning:
#
# Could not infer format, so each element will be parsed individually, falling back to `dateutil`. To ensure parsing is consistent and as-expected, please specify a format.

# %%
airline_data.drop(columns=['Date (MM/DD/YYYY)'],inplace=True)
airline_data.head()
# Out:
#    Carrier Code  Flight Number Origin Airport Destination Airport  clouds_des  \
# 0            9E           5190            JFK                 SYR         100
# 21           9E           5446            JFK                 SYR          78
# 24           9E           5350            JFK                 SYR         100
# 23           9E           5224            JFK                 SYR         100
# 22           9E           5009            JFK                 SYR          25
#
#     dewpt_des  precip_rate_des  pres_des  rh_des  slp_des  snow_rate_des  \
# 0        2.10             0.00      1000      88     1015           0.00
# 21     -13.70             0.00      1003      52     1018           0.00
# 24      -5.00             0.00      1002      72     1018           0.00
# 23      -7.90             0.00      1004      68     1019           0.00
# 22     -10.00             0.00      1006      77     1021           0.00
#
#     temp_des  uv_des  wind_dir_des  wind_gust_spd_des  wind_spd_des   Status  \
# 0       3.90    0.00           285               3.40          1.50    Early
# 21     -5.40    0.90           240              14.80         11.30  On-time
# 24     -0.60    0.60           340               7.00          3.10    Early
# 23     -2.80    0.00           310               3.60          3.60    Early
# 22     -6.70    0.00           300               2.10          2.10  On-time
#
#    Previous Flight Status  Scheduled Arrival Hour  Scheduled Arrival Minutes  \
# 0                 Unknown                      22                         41
# 21                Unknown                      13                         45
# 24                Unknown                      11                         15
# 23                  Early                      18                          1
# 22                  Early                      23                         54
#
#     Scheduled departure Hour  Scheduled departure Minutes       Date
# 0                         21                           10 2023-01-01
# 21                        12                           30 2022-01-10
# 24                         9                           50 2023-01-10
# 23                        16                           35 2023-01-10
# 22                        22                           30 2023-01-10

# %%
airline_data['Status'].replace("Early",0,inplace=True)
airline_data['Status'].replace("Late",1,inplace=True)
airline_data['Status'].replace("On-time",2,inplace=True)
airline_data.head()
# Out:
#    Carrier Code  Flight Number Origin Airport Destination Airport  clouds_des  \
# 0            9E           5190            JFK                 SYR         100
# 21           9E           5446            JFK                 SYR          78
# 24           9E           5350            JFK                 SYR         100
# 23           9E           5224            JFK                 SYR         100
# 22           9E           5009            JFK                 SYR          25
#
#     dewpt_des  precip_rate_des  pres_des  rh_des  slp_des  snow_rate_des  \
# 0        2.10             0.00      1000      88     1015           0.00
# 21     -13.70             0.00      1003      52     1018           0.00
# 24      -5.00             0.00      1002      72     1018           0.00
# 23      -7.90             0.00      1004      68     1019           0.00
# 22     -10.00             0.00      1006      77     1021           0.00
#
#     temp_des  uv_des  wind_dir_des  wind_gust_spd_des  wind_spd_des  Status  \
# 0       3.90    0.00           285               3.40          1.50       0
# 21     -5.40    0.90           240              14.80         11.30       2
# 24     -0.60    0.60           340               7.00          3.10       0
# 23     -2.80    0.00           310               3.60          3.60       0
# 22     -6.70    0.00           300               2.10          2.10       2
#
#    Previous Flight Status  Scheduled Arrival Hour  Scheduled Arrival Minutes  \
# 0                 Unknown                      22                         41
# 21                Unknown                      13                         45
# 24                Unknown                      11                         15
# 23                  Early                      18                          1
# 22                  Early                      23                         54
#
#     Scheduled departure Hour  Scheduled departure Minutes       Date
# 0                         21                           10 2023-01-01
# 21                        12                           30 2022-01-10
# 24                         9                           50 2023-01-10
# 23                        16                           35 2023-01-10
# 22                        22                           30 2023-01-10

# %%
set(airline_data['Origin Airport'])
# Out:
# {'JFK', 'MCO', 'ORD'}

# %%
len(airline_data.columns)
# Out:
# 23

# %%
# Filter the dataset to create two subsets
first_flights = airline_data[airline_data['Previous Flight Status'] == 'Unknown']
subsequent_flights = airline_data[airline_data['Previous Flight Status'] != 'Unknown']
first_flights.head()
# Out:
#    Carrier Code  Flight Number Origin Airport Destination Airport  clouds_des  \
# 0            9E           5190            JFK                 SYR         100
# 21           9E           5446            JFK                 SYR          78
# 24           9E           5350            JFK                 SYR         100
# 25           9E           5446            JFK                 SYR          50
# 28           9E           5350            JFK                 SYR          90
#
#     dewpt_des  precip_rate_des  pres_des  rh_des  slp_des  snow_rate_des  \
# 0        2.10             0.00      1000      88     1015           0.00
# 21     -13.70             0.00      1003      52     1018           0.00
# 24      -5.00             0.00      1002      72     1018           0.00
# 25     -18.30             0.00      1018      66     1034           0.00
# 28      -6.90             0.00      1007      80     1023           0.00
#
#     temp_des  uv_des  wind_dir_des  wind_gust_spd_des  wind_spd_des  Status  \
# 0       3.90    0.00           285               3.40          1.50       0
# 21     -5.40    0.90           240              14.80         11.30       2
# 24     -0.60    0.60           340               7.00          3.10       0
# 25    -13.30    1.20           260               5.70          3.10       0
# 28     -4.00    0.80            80               6.20          3.84       1
#
#    Previous Flight Status  Scheduled Arrival Hour  Scheduled Arrival Minutes  \
# 0                 Unknown                      22                         41
# 21                Unknown                      13                         45
# 24                Unknown                      11                         15
# 25                Unknown                      13                         45
# 28                Unknown                      11                         15
#
#     Scheduled departure Hour  Scheduled departure Minutes       Date
# 0                         21                           10 2023-01-01
# 21                        12                           30 2022-01-10
# 24                         9                           50 2023-01-10
# 25                        12                           30 2022-01-11
# 28                         9                           50 2023-01-11

# %%
# first_flights = airline_data[airline_data['Previous Flight Status'] == 'Unknown']
# subsequent_flights = airline_data[airline_data['Previous Flight Status'] != 'Unknown']
# first_flights.head()

# %%
subsequent_flights.head()
# Out:
#    Carrier Code  Flight Number Origin Airport Destination Airport  clouds_des  \
# 23           9E           5224            JFK                 SYR         100
# 22           9E           5009            JFK                 SYR          25
# 27           9E           5224            JFK                 SYR         100
# 26           9E           5009            JFK                 SYR          25
# 31           9E           5224            JFK                 SYR         100
#
#     dewpt_des  precip_rate_des  pres_des  rh_des  slp_des  snow_rate_des  \
# 23      -7.90             0.00      1004      68     1019           0.00
# 22     -10.00             0.00      1006      77     1021           0.00
# 27      -6.20             0.00      1004      63     1019           0.00
# 26      -5.00             0.00      1003      72     1018           0.00
# 31       2.70             4.00       992      92     1007           0.00
#
#     temp_des  uv_des  wind_dir_des  wind_gust_spd_des  wind_spd_des  Status  \
# 23     -2.80    0.00           310               3.60          3.60       0
# 22     -6.70    0.00           300               2.10          2.10       2
# 27      0.00    0.00            80               7.60          6.20       1
# 26     -0.60    0.00            70              10.80          3.60       1
# 31      3.90    0.00            70               9.60          4.09       2
#
#    Previous Flight Status  Scheduled Arrival Hour  Scheduled Arrival Minutes  \
# 23                  Early                      18                          1
# 22                  Early                      23                         54
# 27                   Late                      18                          1
# 26                   Late                      23                         54
# 31                  Early                      18                          1
#
#     Scheduled departure Hour  Scheduled departure Minutes       Date
# 23                        16                           35 2023-01-10
# 22                        22                           30 2023-01-10
# 27                        16                           35 2023-01-11
# 26                        22                           30 2023-01-11
# 31                        16                           35 2023-01-12

# %%
first_flights.drop(columns=['Previous Flight Status'],inplace=True)
# Out:
# /var/folders/kv/s4mg_r2n60q37wmj416xrvl40000gn/T/ipykernel_79385/1572505522.py:1: SettingWithCopyWarning:
#
#
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy

# %%
first_flights = pd.get_dummies(first_flights, drop_first = True)
first_flights.head()
# Out:
#     Flight Number  clouds_des  dewpt_des  precip_rate_des  pres_des  rh_des  \
# 0            5190         100       2.10             0.00      1000      88
# 21           5446          78     -13.70             0.00      1003      52
# 24           5350         100      -5.00             0.00      1002      72
# 25           5446          50     -18.30             0.00      1018      66
# 28           5350          90      -6.90             0.00      1007      80
#
#     slp_des  snow_rate_des  temp_des  uv_des  wind_dir_des  wind_gust_spd_des  \
# 0      1015           0.00      3.90    0.00           285               3.40
# 21     1018           0.00     -5.40    0.90           240              14.80
# 24     1018           0.00     -0.60    0.60           340               7.00
# 25     1034           0.00    -13.30    1.20           260               5.70
# 28     1023           0.00     -4.00    0.80            80               6.20
#
#     wind_spd_des  Status  Scheduled Arrival Hour  Scheduled Arrival Minutes  \
# 0           1.50       0                      22                         41
# 21         11.30       2                      13                         45
# 24          3.10       0                      11                         15
# 25          3.10       0                      13                         45
# 28          3.84       1                      11                         15
#
#     Scheduled departure Hour  Scheduled departure Minutes       Date  \
# 0                         21                           10 2023-01-01
# 21                        12                           30 2022-01-10
# 24                         9                           50 2023-01-10
# 25                        12                           30 2022-01-11
# 28                         9                           50 2023-01-11
#
#     Carrier Code_B6  Carrier Code_MQ  Carrier Code_UA  Carrier Code_WN  \
# 0             False            False            False            False
# 21            False            False            False            False
# 24            False            False            False            False
# 25            False            False            False            False
# 28            False            False            False            False
#
#     Origin Airport_MCO  Origin Airport_ORD
# 0                False               False
# 21               False               False
# 24               False               False
# 25               False               False
# 28               False               False

# %%
subsequent_flights['Previous Flight Status'].replace("Early",0,inplace=True)
subsequent_flights['Previous Flight Status'].replace("Late",1,inplace=True)
subsequent_flights['Previous Flight Status'].replace("On-time",2,inplace=True)
subsequent_flights.head()
# Out:
# /var/folders/kv/s4mg_r2n60q37wmj416xrvl40000gn/T/ipykernel_79385/1176141493.py:1: SettingWithCopyWarning:
#
#
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
# /var/folders/kv/s4mg_r2n60q37wmj416xrvl40000gn/T/ipykernel_79385/1176141493.py:2: SettingWithCopyWarning:
#
#
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
# /var/folders/kv/s4mg_r2n60q37wmj416xrvl40000gn/T/ipykernel_79385/1176141493.py:3: SettingWithCopyWarning:
#
#
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#    Carrier Code  Flight Number Origin Airport Destination Airport  clouds_des  \
# 23           9E           5224            JFK                 SYR         100
# 22           9E           5009            JFK                 SYR          25
# 27           9E           5224            JFK                 SYR         100
# 26           9E           5009            JFK                 SYR          25
# 31           9E           5224            JFK                 SYR         100
#
#     dewpt_des  precip_rate_des  pres_des  rh_des  slp_des  snow_rate_des  \
# 23      -7.90             0.00      1004      68     1019           0.00
# 22     -10.00             0.00      1006      77     1021           0.00
# 27      -6.20             0.00      1004      63     1019           0.00
# 26      -5.00             0.00      1003      72     1018           0.00
# 31       2.70             4.00       992      92     1007           0.00
#
#     temp_des  uv_des  wind_dir_des  wind_gust_spd_des  wind_spd_des  Status  \
# 23     -2.80    0.00           310               3.60          3.60       0
# 22     -6.70    0.00           300               2.10          2.10       2
# 27      0.00    0.00            80               7.60          6.20       1
# 26     -0.60    0.00            70              10.80          3.60       1
# 31      3.90    0.00            70               9.60          4.09       2
#
#     Previous Flight Status  Scheduled Arrival Hour  Scheduled Arrival Minutes  \
# 23                       0                      18                          1
# 22                       0                      23                         54
# 27                       1                      18                          1
# 26                       1                      23                         54
# 31                       0                      18                          1
#
#     Scheduled departure Hour  Scheduled departure Minutes       Date
# 23                        16                           35 2023-01-10
# 22                        22                           30 2023-01-10
# 27                        16                           35 2023-01-11
# 26                        22                           30 2023-01-11
# 31                        16                           35 2023-01-12

# %%
subsequent_flights = pd.get_dummies(subsequent_flights, drop_first = True)
subsequent_flights.head()
# Out:
#     Flight Number  clouds_des  dewpt_des  precip_rate_des  pres_des  rh_des  \
# 23           5224         100      -7.90             0.00      1004      68
# 22           5009          25     -10.00             0.00      1006      77
# 27           5224         100      -6.20             0.00      1004      63
# 26           5009          25      -5.00             0.00      1003      72
# 31           5224         100       2.70             4.00       992      92
#
#     slp_des  snow_rate_des  temp_des  uv_des  wind_dir_des  wind_gust_spd_des  \
# 23     1019           0.00     -2.80    0.00           310               3.60
# 22     1021           0.00     -6.70    0.00           300               2.10
# 27     1019           0.00      0.00    0.00            80               7.60
# 26     1018           0.00     -0.60    0.00            70              10.80
# 31     1007           0.00      3.90    0.00            70               9.60
#
#     wind_spd_des  Status  Previous Flight Status  Scheduled Arrival Hour  \
# 23          3.60       0                       0                      18
# 22          2.10       2                       0                      23
# 27          6.20       1                       1                      18
# 26          3.60       1                       1                      23
# 31          4.09       2                       0                      18
#
#     Scheduled Arrival Minutes  Scheduled departure Hour  \
# 23                          1                        16
# 22                         54                        22
# 27                          1                        16
# 26                         54                        22
# 31                          1                        16
#
#     Scheduled departure Minutes       Date  Carrier Code_B6  Carrier Code_MQ  \
# 23                           35 2023-01-10            False            False
# 22                           30 2023-01-10            False            False
# 27                           35 2023-01-11            False            False
# 26                           30 2023-01-11            False            False
# 31                           35 2023-01-12            False            False
#
#     Carrier Code_UA  Carrier Code_WN  Origin Airport_MCO  Origin Airport_ORD
# 23            False            False               False               False
# 22            False            False               False               False
# 27            False            False               False               False
# 26            False            False               False               False
# 31            False            False               False               False

# %%
print(len(first_flights.columns))
print(len(subsequent_flights.columns))
# Out:
# 25
# 26

# %%
X_train, X_test, y_train, y_test = train_test_split(first_flights.drop(columns= ['Date','Status'], axis=1), first_flights['Status'], stratify = first_flights['Status'], test_size=0.20, random_state = 35)
X_train.head()
X_test.head()
y_train.head()
y_test.head()
# Out:
#       Flight Number  clouds_des  dewpt_des  precip_rate_des  pres_des  rh_des  \
# 2479           3319          87       3.90             0.00       988      68
# 5395            333         100      11.00             1.00       997      89
# 1815           3518          87      -5.30             0.00       998      39
# 4603            491         100      -4.40             1.00       992      57
# 5289           1559          50      16.40             0.00      1001      49
#
#       slp_des  snow_rate_des  temp_des  uv_des  wind_dir_des  \
# 2479     1003           0.00      9.60    0.90           250
# 5395     1011           0.00     12.80    0.00           205
# 1815     1013           0.00      7.80    0.50            40
# 4603     1006           0.00      3.30    1.80           270
# 5289     1016           0.00     28.20    2.30           330
#
#       wind_gust_spd_des  wind_spd_des  Scheduled Arrival Hour  \
# 2479               9.00          3.35                      16
# 5395               6.90          2.35                      21
# 1815               3.35          3.35                      16
# 4603              14.40         11.80                      13
# 5289               5.20          2.60                      16
#
#       Scheduled Arrival Minutes  Scheduled departure Hour  \
# 2479                         12                        13
# 5395                         11                        18
# 1815                         15                        13
# 4603                         40                        11
# 5289                         50                        13
#
#       Scheduled departure Minutes  Carrier Code_B6  Carrier Code_MQ  \
# 2479                           15            False             True
# 5395                           15            False            False
# 1815                           21            False             True
# 4603                            0            False            False
# 5289                           55            False            False
#
#       Carrier Code_UA  Carrier Code_WN  Origin Airport_MCO  Origin Airport_ORD
# 2479            False            False               False                True
# 5395             True            False               False                True
# 1815            False            False               False                True
# 4603            False             True                True               False
# 5289             True            False               False                True
#       Flight Number  clouds_des  dewpt_des  precip_rate_des  pres_des  rh_des  \
# 1174           5183         100      12.00             0.00       999      66
# 4834           1094          25      -4.10             0.00      1008      56
# 4039            398         100       7.00             0.00       998      44
# 4923            538         100       2.80             0.00       983      82
# 3543            116          25       7.80             0.00      1003      22
#
#       slp_des  snow_rate_des  temp_des  uv_des  wind_dir_des  \
# 1174     1014           0.00     18.40    1.90           180
# 4834     1023           0.00      3.90    0.00           120
# 4039     1013           0.00     19.50    0.50           145
# 4923      997           0.00      5.60    0.00           270
# 3543     1017           0.00     32.20    7.00           155
#
#       wind_gust_spd_des  wind_spd_des  Scheduled Arrival Hour  \
# 1174               4.40          1.95                      12
# 4834               7.60          2.60                      20
# 4039               8.90          3.85                      17
# 4923              15.40         10.80                      21
# 3543               6.40          0.64                      14
#
#       Scheduled Arrival Minutes  Scheduled departure Hour  \
# 1174                         14                        10
# 4834                         59                        18
# 4039                         44                        16
# 4923                         34                        18
# 3543                         42                        13
#
#       Scheduled departure Minutes  Carrier Code_B6  Carrier Code_MQ  \
# 1174                           59            False            False
# 4834                           10            False            False
# 4039                           30             True            False
# 4923                           40            False            False
# 3543                           30             True            False
#
#       Carrier Code_UA  Carrier Code_WN  Origin Airport_MCO  Origin Airport_ORD
# 1174            False            False               False               False
# 4834             True            False               False                True
# 4039            False            False               False               False
# 4923             True            False               False                True
# 3543            False            False               False               False
# 2479    2
# 5395    2
# 1815    0
# 4603    1
# 5289    0
# Name: Status, dtype: int64
# 1174    2
# 4834    0
# 4039    0
# 4923    2
# 3543    0
# Name: Status, dtype: int64

# %%
#scaling the data using standard scaler

if True: 
    from sklearn.preprocessing import StandardScaler
    sc = StandardScaler()
    X_train = pd.DataFrame(sc.fit_transform(X_train), columns = X_train.columns, index = X_train.index)
    X_test = pd.DataFrame(sc.transform(X_test), columns = X_test.columns, index = X_test.index)
    X_train
    X_test
    y_train
    y_test
# Out:
#       Flight Number  clouds_des  dewpt_des  precip_rate_des  pres_des  rh_des  \
# 2479           0.30        0.35      -0.04            -0.21     -1.60    0.30
# 5395          -1.21        0.81       0.70             0.84     -0.44    1.48
# 1815           0.40        0.35      -1.00            -0.21     -0.31   -1.33
# 4603          -1.13        0.81      -0.91             0.84     -1.09   -0.32
# 5289          -0.59       -0.94       1.27            -0.21      0.07   -0.76
# ...             ...         ...        ...              ...       ...     ...
# 2356           0.75        0.81       0.99            -0.21     -0.19    0.24
# 2584           0.40        0.81      -0.69            -0.21      1.62    0.36
# 1705           1.15       -0.31      -1.32            -0.21      1.49    0.30
# 3854          -1.05        0.81       1.55            -0.21     -0.31    0.58
# 89             1.38        0.35      -2.09            -0.21      0.59   -1.44
#
#       slp_des  snow_rate_des  temp_des  uv_des  wind_dir_des  \
# 2479    -1.54          -0.10     -0.22   -0.19          0.46
# 5395    -0.55          -0.10      0.09   -0.78         -0.05
# 1815    -0.30          -0.10     -0.39   -0.45         -1.90
# 4603    -1.17          -0.10     -0.83    0.40          0.68
# 5289     0.08          -0.10      1.59    0.73          1.35
# ...       ...            ...       ...     ...           ...
# 2356    -0.30          -0.10      0.80   -0.39          0.85
# 2584     1.58          -0.10     -0.88   -0.45          0.57
# 1705     1.58          -0.10     -1.47   -0.78          0.17
# 3854    -0.30          -0.10      1.21    0.21          0.62
# 89       0.70          -0.10     -1.45   -0.19         -0.50
#
#       wind_gust_spd_des  wind_spd_des  Scheduled Arrival Hour  \
# 2479               0.45         -0.28                    0.51
# 5395              -0.17         -0.71                    1.24
# 1815              -1.20         -0.28                    0.51
# 4603               2.03          3.36                    0.07
# 5289              -0.66         -0.60                    0.51
# ...                 ...           ...                     ...
# 2356               0.07          0.10                    0.65
# 2584               0.04         -0.17                    0.36
# 1705              -0.49         -0.49                   -1.84
# 3854               0.22         -0.12                   -0.37
# 89                 0.39          0.78                    0.07
#
#       Scheduled Arrival Minutes  Scheduled departure Hour  \
# 2479                      -0.87                     -0.32
# 5395                      -0.92                      0.71
# 1815                      -0.70                     -0.32
# 4603                       0.67                     -0.74
# 5289                       1.22                     -0.32
# ...                         ...                       ...
# 2356                       1.00                     -0.12
# 2584                       1.55                     -0.32
# 1705                      -0.04                      1.54
# 3854                       1.22                     -1.36
# 89                         0.95                     -0.53
#
#       Scheduled departure Minutes  Carrier Code_B6  Carrier Code_MQ  \
# 2479                        -0.85            -0.59             2.19
# 5395                        -0.85            -0.59            -0.46
# 1815                        -0.52            -0.59             2.19
# 4603                        -1.66            -0.59            -0.46
# 5289                         1.32            -0.59            -0.46
# ...                           ...              ...              ...
# 2356                         1.38            -0.59             2.19
# 2584                        -1.66            -0.59             2.19
# 1705                         1.05            -0.59            -0.46
# 3854                        -1.28             1.68            -0.46
# 89                          -0.03            -0.59            -0.46
#
#       Carrier Code_UA  Carrier Code_WN  Origin Airport_MCO  Origin Airport_ORD
# 2479            -0.55            -0.26               -0.41                1.20
# 5395             1.80            -0.26               -0.41                1.20
# 1815            -0.55            -0.26               -0.41                1.20
# 4603            -0.55             3.82                2.45               -0.83
# 5289             1.80            -0.26               -0.41                1.20
# ...               ...              ...                 ...                 ...
# 2356            -0.55            -0.26               -0.41                1.20
# 2584            -0.55            -0.26               -0.41                1.20
# 1705            -0.55            -0.26               -0.41               -0.83
# 3854            -0.55            -0.26                2.45               -0.83
# 89              -0.55            -0.26               -0.41               -0.83
#
# [2240 rows x 23 columns]
#       Flight Number  clouds_des  dewpt_des  precip_rate_des  pres_des  rh_des  \
# 1174           1.25        0.81       0.81            -0.21     -0.19    0.19
# 4834          -0.83       -1.81      -0.87            -0.21      0.97   -0.37
# 4039          -1.18        0.81       0.28            -0.21     -0.31   -1.05
# 4923          -1.11        0.81      -0.15            -0.21     -2.24    1.08
# 3543          -1.32       -1.81       0.37            -0.21      0.33   -2.28
# ...             ...         ...        ...              ...       ...     ...
# 4207          -1.05        0.67       1.06            -0.21      0.07    0.02
# 1710           1.26        0.04      -1.04            -0.21      1.87    0.02
# 3243          -1.38        0.81      -0.46            -0.21     -1.60    1.25
# 1885           0.71        0.35      -0.95            -0.21     -0.06   -2.11
# 5495          -1.11        0.81      -0.47            -0.21      0.07    0.86
#
#       slp_des  snow_rate_des  temp_des  uv_des  wind_dir_des  \
# 1174    -0.17          -0.10      0.64    0.47         -0.33
# 4834     0.95          -0.10     -0.77   -0.78         -1.01
# 4039    -0.30          -0.10      0.75   -0.45         -0.72
# 4923    -2.29          -0.10     -0.61   -0.78          0.68
# 3543     0.20          -0.10      1.98    3.82         -0.61
# ...       ...            ...       ...     ...           ...
# 4207     0.08          -0.10      0.97   -0.12         -1.62
# 1710     1.95          -0.10     -1.09   -0.19         -0.56
# 3243    -1.67          -0.10     -0.94   -0.78          1.24
# 1885    -0.05          -0.10      0.31    0.80          0.12
# 5495     0.08          -0.10     -0.83   -0.78         -1.01
#
#       wind_gust_spd_des  wind_spd_des  Scheduled Arrival Hour  \
# 1174              -0.90         -0.88                   -0.08
# 4834               0.04         -0.60                    1.09
# 4039               0.42         -0.06                    0.65
# 4923               2.32          2.93                    1.24
# 3543              -0.31         -1.45                    0.21
# ...                 ...           ...                     ...
# 4207               0.98         -0.63                   -0.37
# 1710              -0.66         -1.39                   -0.23
# 3243               1.74          1.81                   -1.84
# 1885               0.83          1.60                   -0.23
# 5495              -1.13         -0.60                    1.24
#
#       Scheduled Arrival Minutes  Scheduled departure Hour  \
# 1174                      -0.76                     -0.94
# 4834                       1.72                      0.71
# 4039                       0.89                      0.30
# 4923                       0.34                      0.71
# 3543                       0.78                     -0.32
# ...                         ...                       ...
# 4207                      -0.48                     -1.57
# 1710                      -0.76                     -1.15
# 3243                      -1.31                      1.54
# 1885                      -1.14                     -1.36
# 5495                      -1.47                      0.71
#
#       Scheduled departure Minutes  Carrier Code_B6  Carrier Code_MQ  \
# 1174                         1.54            -0.59            -0.46
# 4834                        -1.12            -0.59            -0.46
# 4039                        -0.03             1.68            -0.46
# 4923                         0.51            -0.59            -0.46
# 3543                        -0.03             1.68            -0.46
# ...                           ...              ...              ...
# 4207                         0.24             1.68            -0.46
# 1710                         1.05            -0.59            -0.46
# 3243                         0.78             1.68            -0.46
# 1885                        -0.41            -0.59             2.19
# 5495                        -1.12            -0.59            -0.46
#
#       Carrier Code_UA  Carrier Code_WN  Origin Airport_MCO  Origin Airport_ORD
# 1174            -0.55            -0.26               -0.41               -0.83
# 4834             1.80            -0.26               -0.41                1.20
# 4039            -0.55            -0.26               -0.41               -0.83
# 4923             1.80            -0.26               -0.41                1.20
# 3543            -0.55            -0.26               -0.41               -0.83
# ...               ...              ...                 ...                 ...
# 4207            -0.55            -0.26                2.45               -0.83
# 1710            -0.55            -0.26               -0.41               -0.83
# 3243            -0.55            -0.26               -0.41               -0.83
# 1885            -0.55            -0.26               -0.41                1.20
# 5495             1.80            -0.26               -0.41                1.20
#
# [561 rows x 23 columns]
# 2479    2
# 5395    2
# 1815    0
# 4603    1
# 5289    0
#        ..
# 2356    0
# 2584    0
# 1705    0
# 3854    0
# 89      2
# Name: Status, Length: 2240, dtype: int64
# 1174    2
# 4834    0
# 4039    0
# 4923    2
# 3543    0
#        ..
# 4207    2
# 1710    2
# 3243    2
# 1885    2
# 5495    1
# Name: Status, Length: 561, dtype: int64

# %%
len(X_train)
len(y_train)
len(X_test)
len(y_test)
# Out:
# 2240
# 2240
# 561
# 561

# %%
# from sklearn.model_selection import cross_val_score
# from sklearn.ensemble import RandomForestClassifier, BaggingClassifier, GradientBoostingClassifier
# from sklearn.linear_model import LogisticRegression
# from sklearn.svm import SVC
# from sklearn.neighbors import KNeighborsClassifier
# from sklearn.model_selection import StratifiedKFold

# # Define classifiers with different parameters
# classifiers = {
#     'Random Forest': RandomForestClassifier(random_state=50, min_samples_leaf=6, max_features="sqrt", n_estimators=1000),
#     'Bagging': BaggingClassifier(base_estimator=RandomForestClassifier(random_state=50), n_estimators=100, max_samples=100),
#     'Gradient Boosting': GradientBoostingClassifier(n_estimators=100, learning_rate=0.1, max_depth=3),
#     'Logistic Regression': LogisticRegression(),
# #     'Support Vector Machine': SVC(),
# #     'K-Nearest Neighbors': KNeighborsClassifier()
# }

# # Initialize lists to store results
# results = {}
# std_devs = {}

# # Define cross-validation strategy
# cv = StratifiedKFold(n_splits=5, shuffle=True, random_state=50)

# # Perform cross-validation for each classifier
# for clf_name, clf in classifiers.items():
#     scores = cross_val_score(clf,X_train, y_train, cv=cv, scoring='accuracy')
#     results[clf_name] = scores.mean()
#     std_devs[clf_name] = scores.std()

# # Print results
# print("Mean Accuracy Scores:")
# for clf_name, mean_acc in results.items():
#     print(f"{clf_name}: {mean_acc:.4f} ± {std_devs[clf_name]:.4f}")

# # Select classifier with highest mean accuracy
# best_clf = max(results, key=results.get)
# print(f"\nBest Classifier: {best_clf}")

# %% [markdown]
# <h6>used the above code to select the best model based on accuarcy score</h6>

# %%
# Define parameter grid
# param_grid = {
#     'n_estimators': [100, 1000, 150],
#     'max_depth': [None, 5, 10],
#     'min_samples_leaf': [1, 3, 5],
#     'max_features': [None, 'sqrt', 'log2']
# }

# best_accuracy = 0  # Initialize with 0
# best_params = None

# # Perform grid search
# for n_estimators in param_grid['n_estimators']:
#     for max_depth in param_grid['max_depth']:
#         for min_samples_leaf in param_grid['min_samples_leaf']:
#             for max_features in param_grid['max_features']:
#                 # Create Random Forest Classifier with current parameters
#                 rf = RandomForestClassifier(n_estimators=n_estimators, 
#                                              max_depth=max_depth, 
#                                              min_samples_leaf=min_samples_leaf,
#                                              max_features=max_features,
#                                              random_state=50)
        
#                 # Perform cross-validation to get predicted values
#                 y_pred = cross_val_predict(rf, X_train, y_train, cv=5)
        
#                 # Calculate accuracy
#                 accuracy = accuracy_score(y_train, y_pred)
        
#                 # Check if current parameters yield a better accuracy
#                 if accuracy > best_accuracy:
#                     best_accuracy = accuracy
#                     best_params = {'n_estimators': n_estimators, 
#                                    'max_depth': max_depth, 
#                                    'min_samples_leaf': min_samples_leaf,
#                                    'max_features': max_features}
        
#                 print(f"Parameters: n_estimators={n_estimators}, max_depth={max_depth}, min_samples_leaf={min_samples_leaf}, max_features={max_features}, Accuracy: {accuracy}")

# print("Best Parameters:", best_params)
# print("Best Accuracy:", best_accuracy)

# %% [markdown]
# <h6>Tried execution of selected model with different parameters for parameter tuning</h6>

# %%
rf_1 = RandomForestClassifier(n_estimators=1000, max_depth=None, min_samples_leaf=3, max_features="sqrt", random_state=42)
rf_1 = rf_1.fit(X_train, y_train)

# %%
from sklearn.metrics import accuracy_score

# Predict the labels for the test data
y_pred_test = rf_1.predict(X_test)

# Calculate the accuracy score on the test data
accuracy_test = accuracy_score(y_test, y_pred_test)

print("Accuracy on test data:", accuracy_test)
# Out:
# Accuracy on test data: 0.5383244206773619

# %%
X_train_sub, X_test_sub, y_train_sub, y_test_sub = train_test_split(subsequent_flights.drop(columns= ['Date', 'Status'], axis=1), subsequent_flights['Status'], stratify = subsequent_flights['Status'], test_size=0.20, random_state = 35)
X_train_sub.head()
X_test_sub.head()
y_train_sub.head()
y_test_sub.head()
# Out:
#       Flight Number  clouds_des  dewpt_des  precip_rate_des  pres_des  rh_des  \
# 829            5118         100      18.00             0.00       998      60
# 2301           3545           0      15.40             0.00      1004      80
# 677            4730          87      14.10             0.00       999      46
# 1720           5090         100     -15.70             0.00       979      86
# 3550           2516          87      13.80             0.00       998      61
#
#       slp_des  snow_rate_des  temp_des  uv_des  wind_dir_des  \
# 829      1012           0.00     26.40    2.30           135
# 2301     1019           0.00     18.90    0.00           115
# 677      1014           0.00     26.60    2.00           180
# 1720      994           0.00    -13.90    0.00           220
# 3550     1013           0.00     21.60    0.00           280
#
#       wind_gust_spd_des  wind_spd_des  Previous Flight Status  \
# 829                4.80          2.04                       1
# 2301               4.20          1.65                       2
# 677               11.30          8.25                       1
# 1720              13.40          8.80                       2
# 3550               3.10          1.30                       0
#
#       Scheduled Arrival Hour  Scheduled Arrival Minutes  \
# 829                       15                         23
# 2301                      23                         11
# 677                       16                         25
# 1720                      23                         58
# 3550                      23                         19
#
#       Scheduled departure Hour  Scheduled departure Minutes  Carrier Code_B6  \
# 829                         13                           59            False
# 2301                        20                           20            False
# 677                         15                           10            False
# 1720                        22                           30            False
# 3550                        21                           59             True
#
#       Carrier Code_MQ  Carrier Code_UA  Carrier Code_WN  Origin Airport_MCO  \
# 829             False            False            False               False
# 2301             True            False            False               False
# 677             False            False            False               False
# 1720            False            False            False               False
# 3550            False            False            False               False
#
#       Origin Airport_ORD
# 829                False
# 2301                True
# 677                False
# 1720               False
# 3550               False
#       Flight Number  clouds_des  dewpt_des  precip_rate_des  pres_des  rh_des  \
# 4289             16          87      -6.00             0.00      1000      58
# 2096           3402          93      20.00             0.00       999      75
# 5094           1503         100      20.40             1.50       996      84
# 4472            656          25      -5.10             0.00      1013      50
# 2250           3911          66      14.90             0.00       993      70
#
#       slp_des  snow_rate_des  temp_des  uv_des  wind_dir_des  \
# 4289     1015           0.00      1.40    0.90           220
# 2096     1013           0.00     24.70    0.00           305
# 5094     1010           0.00     23.30    0.00           210
# 4472     1029           0.00      4.40    0.00           210
# 2250     1007           0.00     20.60    0.00           240
#
#       wind_gust_spd_des  wind_spd_des  Previous Flight Status  \
# 4289              11.20          6.45                       2
# 2096               2.80          2.60                       2
# 5094               7.60          4.09                       0
# 4472               8.10          4.34                       0
# 2250               8.40          4.09                       1
#
#       Scheduled Arrival Hour  Scheduled Arrival Minutes  \
# 4289                       9                         20
# 2096                      21                         32
# 5094                      23                         59
# 4472                      19                         13
# 2250                      20                          0
#
#       Scheduled departure Hour  Scheduled departure Minutes  Carrier Code_B6  \
# 4289                         8                           10             True
# 2096                        18                           36            False
# 5094                        21                            5            False
# 4472                        16                           25             True
# 2250                        17                           13            False
#
#       Carrier Code_MQ  Carrier Code_UA  Carrier Code_WN  Origin Airport_MCO  \
# 4289            False            False            False               False
# 2096             True            False            False               False
# 5094            False             True            False               False
# 4472            False            False            False                True
# 2250             True            False            False               False
#
#       Origin Airport_ORD
# 4289               False
# 2096                True
# 5094                True
# 4472               False
# 2250                True
# 829     2
# 2301    1
# 677     0
# 1720    1
# 3550    1
# Name: Status, dtype: int64
# 4289    0
# 2096    0
# 5094    2
# 4472    1
# 2250    0
# Name: Status, dtype: int64

# %%
if True: 
    from sklearn.preprocessing import StandardScaler
    sc = StandardScaler()
    X_train_sub = pd.DataFrame(sc.fit_transform(X_train_sub), columns = X_train_sub.columns, index = X_train_sub.index)
    X_test_sub = pd.DataFrame(sc.transform(X_test_sub), columns = X_test_sub.columns, index = X_test_sub.index)
    X_train_sub
    X_test_sub
    y_train_sub
    y_test_sub
# Out:
#       Flight Number  clouds_des  dewpt_des  precip_rate_des  pres_des  rh_des  \
# 829            1.08        0.83       1.51            -0.09     -0.34   -0.21
# 2301           0.26       -2.50       1.23            -0.09      0.43    0.86
# 677            0.88        0.39       1.09            -0.09     -0.21   -0.96
# 1720           1.07        0.83      -2.15            -0.09     -2.75    1.18
# 3550          -0.28        0.39       1.06            -0.09     -0.34   -0.16
# ...             ...         ...        ...              ...       ...     ...
# 2192           0.45        0.39       1.73            -0.09     -0.72    1.39
# 3435          -0.28       -0.84       0.01            -0.09      0.43   -0.27
# 2047           0.19        0.39       1.24            -0.09     -0.59    1.12
# 1438           1.12        0.83      -0.12            -0.09      0.68   -0.75
# 337            0.88        0.83      -0.10            -0.04     -2.12    0.54
#
#       slp_des  snow_rate_des  temp_des  uv_des  wind_dir_des  \
# 829     -0.44          -0.12      1.49    1.10         -0.82
# 2301     0.42          -0.12      0.75   -0.62         -1.04
# 677     -0.20          -0.12      1.51    0.88         -0.31
# 1720    -2.67          -0.12     -2.52   -0.62          0.13
# 3550    -0.32          -0.12      1.01   -0.62          0.80
# ...       ...            ...       ...     ...           ...
# 2192    -0.82          -0.12      1.02   -0.62          0.69
# 3435     0.42          -0.12      0.05   -0.62         -0.65
# 2047    -0.69          -0.12      0.67   -0.62         -0.31
# 1438     0.67          -0.12      0.18    0.13          0.64
# 337     -2.05          -0.12     -0.39    0.20          0.64
#
#       wind_gust_spd_des  wind_spd_des  Previous Flight Status  \
# 829               -0.66         -0.77                    0.31
# 2301              -0.84         -0.95                    1.57
# 677                1.25          2.06                    0.31
# 1720               1.86          2.32                    1.57
# 3550              -1.16         -1.11                   -0.95
# ...                 ...           ...                     ...
# 2192              -1.60         -1.52                    0.31
# 3435              -0.78         -1.54                    0.31
# 2047              -1.25         -1.02                   -0.95
# 1438              -0.40         -1.54                   -0.95
# 337                0.22          0.64                   -0.95
#
#       Scheduled Arrival Hour  Scheduled Arrival Minutes  \
# 829                    -0.82                      -0.37
# 2301                    1.14                      -0.98
# 677                    -0.58                      -0.27
# 1720                    1.14                       1.41
# 3550                    1.14                      -0.57
# ...                      ...                        ...
# 2192                    0.40                      -1.54
# 3435                    1.14                      -0.57
# 2047                    0.65                       0.09
# 1438                   -1.56                      -0.57
# 337                    -0.58                      -0.52
#
#       Scheduled departure Hour  Scheduled departure Minutes  Carrier Code_B6  \
# 829                      -0.85                         1.75            -0.81
# 2301                      0.86                        -0.47            -0.81
# 677                      -0.36                        -1.05            -0.81
# 1720                      1.36                         0.10            -0.81
# 3550                      1.11                         1.75             1.23
# ...                        ...                          ...              ...
# 2192                      0.13                        -0.88            -0.81
# 3435                      1.11                         1.75             1.23
# 2047                      0.37                         0.44            -0.81
# 1438                     -1.59                         1.75            -0.81
# 337                      -0.36                        -1.62            -0.81
#
#       Carrier Code_MQ  Carrier Code_UA  Carrier Code_WN  Origin Airport_MCO  \
# 829             -0.47            -0.24             0.00               -0.40
# 2301             2.11            -0.24             0.00               -0.40
# 677             -0.47            -0.24             0.00               -0.40
# 1720            -0.47            -0.24             0.00               -0.40
# 3550            -0.47            -0.24             0.00               -0.40
# ...               ...              ...              ...                 ...
# 2192             2.11            -0.24             0.00               -0.40
# 3435            -0.47            -0.24             0.00               -0.40
# 2047             2.11            -0.24             0.00               -0.40
# 1438            -0.47            -0.24             0.00               -0.40
# 337             -0.47            -0.24             0.00               -0.40
#
#       Origin Airport_ORD
# 829                -0.56
# 2301                1.78
# 677                -0.56
# 1720               -0.56
# 3550               -0.56
# ...                  ...
# 2192                1.78
# 3435               -0.56
# 2047                1.78
# 1438               -0.56
# 337                -0.56
#
# [2248 rows x 24 columns]
#       Flight Number  clouds_des  dewpt_des  precip_rate_des  pres_des  rh_des  \
# 4289          -1.59        0.39      -1.09            -0.09     -0.08   -0.32
# 2096           0.19        0.59       1.73            -0.09     -0.21    0.59
# 5094          -0.81        0.83       1.77             0.52     -0.59    1.07
# 4472          -1.25       -1.67      -1.00            -0.09      1.57   -0.75
# 2250           0.45       -0.31       1.17            -0.09     -0.97    0.32
# ...             ...         ...        ...              ...       ...     ...
# 1268           1.02       -1.67       1.25            -0.09      0.68    1.07
# 1540           0.95        0.83      -1.17            -0.09      1.06   -0.64
# 3610          -0.28        0.39       0.98            -0.09      0.30    0.16
# 3277          -1.25        0.39      -0.14            -0.09     -1.74    0.22
# 3988          -0.28       -2.30       1.27            -0.09      0.68    1.02
#
#       slp_des  snow_rate_des  temp_des  uv_des  wind_dir_des  \
# 4289    -0.07          -0.12     -1.00    0.06          0.13
# 2096    -0.32          -0.12      1.32   -0.62          1.08
# 5094    -0.69          -0.12      1.18   -0.62          0.02
# 4472     1.66          -0.12     -0.70   -0.62          0.02
# 2250    -1.06          -0.12      0.91   -0.62          0.36
# ...       ...            ...       ...     ...           ...
# 1268     0.55          -0.12      0.69   -0.62         -0.76
# 1540     1.16          -0.12     -0.93    0.06         -1.37
# 3610     0.30          -0.12      0.79   -0.62         -1.60
# 3277    -1.68          -0.12     -0.31    1.55          1.03
# 3988     0.55          -0.12      0.74   -0.62         -0.93
#
#       wind_gust_spd_des  wind_spd_des  Previous Flight Status  \
# 4289               1.22          1.24                    1.57
# 2096              -1.25         -0.52                    1.57
# 5094               0.16          0.16                   -0.95
# 4472               0.31          0.28                   -0.95
# 2250               0.40          0.16                    0.31
# ...                 ...           ...                     ...
# 1268              -1.45         -0.75                   -0.95
# 1540               0.69          0.57                    0.31
# 3610              -0.89         -0.43                    1.57
# 3277               1.10         -0.29                    0.31
# 3988              -1.58         -0.95                    0.31
#
#       Scheduled Arrival Hour  Scheduled Arrival Minutes  \
# 4289                   -2.29                      -0.52
# 2096                    0.65                       0.09
# 5094                    1.14                       1.46
# 4472                    0.16                      -0.88
# 2250                    0.40                      -1.54
# ...                      ...                        ...
# 1268                    1.14                       1.46
# 1540                   -1.56                      -0.62
# 3610                    1.14                      -1.43
# 3277                   -1.31                       1.31
# 3988                    1.14                      -0.77
#
#       Scheduled departure Hour  Scheduled departure Minutes  Carrier Code_B6  \
# 4289                     -2.08                        -1.05             1.23
# 2096                      0.37                         0.44            -0.81
# 5094                      1.11                        -1.33            -0.81
# 4472                     -0.12                        -0.19             1.23
# 2250                      0.13                        -0.88            -0.81
# ...                        ...                          ...              ...
# 1268                      1.36                         0.27            -0.81
# 1540                     -1.59                         1.47            -0.81
# 3610                      1.11                         0.50             1.23
# 3277                     -1.34                        -0.99             1.23
# 3988                      1.11                         1.53             1.23
#
#       Carrier Code_MQ  Carrier Code_UA  Carrier Code_WN  Origin Airport_MCO  \
# 4289            -0.47            -0.24             0.00               -0.40
# 2096             2.11            -0.24             0.00               -0.40
# 5094            -0.47             4.10             0.00               -0.40
# 4472            -0.47            -0.24             0.00                2.48
# 2250             2.11            -0.24             0.00               -0.40
# ...               ...              ...              ...                 ...
# 1268            -0.47            -0.24             0.00               -0.40
# 1540            -0.47            -0.24             0.00               -0.40
# 3610            -0.47            -0.24             0.00               -0.40
# 3277            -0.47            -0.24             0.00                2.48
# 3988            -0.47            -0.24             0.00               -0.40
#
#       Origin Airport_ORD
# 4289               -0.56
# 2096                1.78
# 5094                1.78
# 4472               -0.56
# 2250                1.78
# ...                  ...
# 1268               -0.56
# 1540               -0.56
# 3610               -0.56
# 3277               -0.56
# 3988               -0.56
#
# [563 rows x 24 columns]
# 829     2
# 2301    1
# 677     0
# 1720    1
# 3550    1
#        ..
# 2192    1
# 3435    1
# 2047    1
# 1438    0
# 337     1
# Name: Status, Length: 2248, dtype: int64
# 4289    0
# 2096    0
# 5094    2
# 4472    1
# 2250    0
#        ..
# 1268    0
# 1540    2
# 3610    1
# 3277    0
# 3988    1
# Name: Status, Length: 563, dtype: int64

# %%
rf_2 = RandomForestClassifier(n_estimators=1000, max_depth=None, min_samples_leaf=3, max_features="sqrt", random_state=42)
rf_2 = rf_2.fit(X_train_sub, y_train_sub)

# %%
from sklearn.metrics import accuracy_score

# Predict the labels for the test data
y_pred_test_sub = rf_2.predict(X_test_sub)

# Calculate the accuracy score on the test data
accuracy_test = accuracy_score(y_test_sub, y_pred_test_sub)

print("Accuracy on test data:", accuracy_test)
# Out:
# Accuracy on test data: 0.5293072824156305

# %%
test_sub_output = pd.DataFrame(rf_2.predict(X_test_sub), index = X_test_sub.index, columns = ['pred_arr_status'])
test_sub_output.head(50)
# Out:
#       pred_arr_status
# 4289                2
# 2096                1
# 5094                1
# 4472                0
# 2250                1
# 2881                0
# 3357                1
# 1308                0
# 1668                0
# 1069                0
# 4303                2
# 3889                1
# 965                 0
# 5420                0
# 4826                0
# 2475                2
# 5414                0
# 4167                0
# 4175                0
# 4041                1
# 2369                2
# 3404                1
# 1878                0
# 1122                0
# 4083                1
# 2126                1
# 3385                1
# 610                 0
# 1051                0
# 151                 0
# 2439                2
# 4448                1
# 4243                1
# 4272                0
# 1590                0
# 2087                1
# 1387                0
# 2563                0
# 5488                0
# 3910                1
# 4065                0
# 4293                1
# 2787                0
# 3682                1
# 1409                0
# 4582                0
# 2466                0
# 2808                0
# 1103                0
# 2431                0

# %%
set(test_sub_output['pred_arr_status'])
# Out:
# {0, 1, 2}

# %%
value_counts = test_sub_output['pred_arr_status'].value_counts()
value_counts
# Out:
# pred_arr_status
# 0    319
# 1    208
# 2     36
# Name: count, dtype: int64

# %%
# fetch data 
test_data = pd.read_csv('test_Flight_weather_data.csv')
test_data.head()
# Out:
#       Date CarrierCode  FlightNumber Origin Dest  clouds_des  temp_des  \
# 0  4/19/24          UA           538    ORD  SYR          84     12.40
# 1  4/19/24          MQ          3402    ORD  SYR          84     12.40
# 2  4/19/24          B6           116    JFK  SYR          84     12.40
# 3  4/19/24          9E          5340    JFK  SYR          84     12.40
# 4  4/19/24          WN           491    MCO  SYR          84     12.40
#
#    max_temp_des  min_temp_des  wind_dir_des  wind_spd_des  wind_gust_spd_des  \
# 0         16.70          8.90           171          4.20               4.60
# 1         16.70          8.90           171          4.20               4.60
# 2         16.70          8.90           171          4.20               4.60
# 3         16.70          8.90           171          4.20               4.60
# 4         16.70          8.90           171          4.20               4.60
#
#    snow_rate_des  snow_depth_des  precip_rate_des  pres_des  uv_des  \
# 0              0               0            42.56  1,003.50    8.30
# 1              0               0            42.56  1,003.50    8.30
# 2              0               0            42.56  1,003.50    8.30
# 3              0               0            42.56  1,003.50    8.30
# 4              0               0            42.56  1,003.50    8.30
#
#    dewpt_des  rh_des  slp_des Scheduled departure time Scheduled Arrival Time
# 0       3.90      57 1,019.50                  6:52 PM                9:47 PM
# 1       3.90      57 1,019.50                  7:59 PM               10:52 PM
# 2       3.90      57 1,019.50                  1:34 PM                2:51 PM
# 3       3.90      57 1,019.50                  2:55 PM                4:21 PM
# 4       3.90      57 1,019.50                 11:35 AM                2:20 PM

# %%
test_data
# Out:
#        Date CarrierCode  FlightNumber Origin Dest  clouds_des  temp_des  \
# 0   4/19/24          UA           538    ORD  SYR          84     12.40
# 1   4/19/24          MQ          3402    ORD  SYR          84     12.40
# 2   4/19/24          B6           116    JFK  SYR          84     12.40
# 3   4/19/24          9E          5340    JFK  SYR          84     12.40
# 4   4/19/24          WN           491    MCO  SYR          84     12.40
# 5   4/19/24          B6            56    MCO  SYR          84     12.40
# 6   4/20/24          UA           538    ORD  SYR          49     10.10
# 7   4/20/24          MQ          3402    ORD  SYR          49     10.10
# 8   4/20/24          B6           116    JFK  SYR          49     10.10
# 9   4/20/24          9E          5340    JFK  SYR          49     10.10
# 10  4/20/24          B6            56    MCO  SYR          49     10.10
# 11  4/21/24          UA           538    ORD  SYR          90     12.20
# 12  4/21/24          MQ          3402    ORD  SYR          90     12.20
# 13  4/21/24          B6           116    JFK  SYR          90     12.20
# 14  4/21/24          9E          5340    JFK  SYR          90     12.20
# 15  4/21/24          WN           491    MCO  SYR          90     12.20
# 16  4/21/24          B6            56    MCO  SYR          90     12.20
# 17  4/22/24          UA           538    ORD  SYR          72     12.40
# 18  4/22/24          MQ          3402    ORD  SYR          72     12.40
# 19  4/22/24          B6           116    JFK  SYR          72     12.40
# 20  4/22/24          9E          5340    JFK  SYR          72     12.40
# 21  4/22/24          WN           491    MCO  SYR          72     12.40
# 22  4/22/24          B6            56    MCO  SYR          72     12.40
#
#     max_temp_des  min_temp_des  wind_dir_des  wind_spd_des  wind_gust_spd_des  \
# 0          16.70          8.90           171          4.20               4.60
# 1          16.70          8.90           171          4.20               4.60
# 2          16.70          8.90           171          4.20               4.60
# 3          16.70          8.90           171          4.20               4.60
# 4          16.70          8.90           171          4.20               4.60
# 5          16.70          8.90           171          4.20               4.60
# 6          19.80          4.60           227          3.40               6.50
# 7          19.80          4.60           227          3.40               6.50
# 8          19.80          4.60           227          3.40               6.50
# 9          19.80          4.60           227          3.40               6.50
# 10         19.80          4.60           227          3.40               6.50
# 11         17.90          6.80           110          1.90               2.70
# 12         17.90          6.80           110          1.90               2.70
# 13         17.90          6.80           110          1.90               2.70
# 14         17.90          6.80           110          1.90               2.70
# 15         17.90          6.80           110          1.90               2.70
# 16         17.90          6.80           110          1.90               2.70
# 17         18.60          8.50           131          5.50              10.90
# 18         18.60          8.50           131          5.50              10.90
# 19         18.60          8.50           131          5.50              10.90
# 20         18.60          8.50           131          5.50              10.90
# 21         18.60          8.50           131          5.50              10.90
# 22         18.60          8.50           131          5.50              10.90
#
#     snow_rate_des  snow_depth_des  precip_rate_des  pres_des  uv_des  \
# 0               0               0            42.56  1,003.50    8.30
# 1               0               0            42.56  1,003.50    8.30
# 2               0               0            42.56  1,003.50    8.30
# 3               0               0            42.56  1,003.50    8.30
# 4               0               0            42.56  1,003.50    8.30
# 5               0               0            42.56  1,003.50    8.30
# 6               0               0            25.00  1,007.50    8.40
# 7               0               0            25.00  1,007.50    8.40
# 8               0               0            25.00  1,007.50    8.40
# 9               0               0            25.00  1,007.50    8.40
# 10              0               0            25.00  1,007.50    8.40
# 11              0               0            13.19  1,002.80    8.40
# 12              0               0            13.19  1,002.80    8.40
# 13              0               0            13.19  1,002.80    8.40
# 14              0               0            13.19  1,002.80    8.40
# 15              0               0            13.19  1,002.80    8.40
# 16              0               0            13.19  1,002.80    8.40
# 17              0               0            17.38    999.50    8.50
# 18              0               0            17.38    999.50    8.50
# 19              0               0            17.38    999.50    8.50
# 20              0               0            17.38    999.50    8.50
# 21              0               0            17.38    999.50    8.50
# 22              0               0            17.38    999.50    8.50
#
#     dewpt_des  rh_des  slp_des Scheduled departure time Scheduled Arrival Time
# 0        3.90      57 1,019.50                  6:52 PM                9:47 PM
# 1        3.90      57 1,019.50                  7:59 PM               10:52 PM
# 2        3.90      57 1,019.50                  1:34 PM                2:51 PM
# 3        3.90      57 1,019.50                  2:55 PM                4:21 PM
# 4        3.90      57 1,019.50                 11:35 AM                2:20 PM
# 5        3.90      57 1,019.50                  1:35 PM                4:25 PM
# 6        6.30      78 1,023.70                  6:52 PM                9:47 PM
# 7        6.30      78 1,023.70                  7:59 PM               10:52 PM
# 8        6.30      78 1,023.70                  1:25 PM                2:41 PM
# 9        6.30      78 1,023.70                  2:55 PM                4:21 PM
# 10       6.30      78 1,023.70                  1:35 PM                4:25 PM
# 11       9.60      85 1,018.70                  6:52 PM                9:47 PM
# 12       9.60      85 1,018.70                  7:59 PM               10:52 PM
# 13       9.60      85 1,018.70                  1:35 PM                2:51 PM
# 14       9.60      85 1,018.70                  2:55 PM                4:21 PM
# 15       9.60      85 1,018.70                 11:05 AM                1:50 PM
# 16       9.60      85 1,018.70                  1:35 PM                4:25 PM
# 17       8.50      78 1,015.40                  6:52 PM                9:47 PM
# 18       8.50      78 1,015.40                  7:59 PM               10:52 PM
# 19       8.50      78 1,015.40                  1:35 PM                2:51 PM
# 20       8.50      78 1,015.40                  2:55 PM                4:21 PM
# 21       8.50      78 1,015.40                 11:35 AM                2:20 PM
# 22       8.50      78 1,015.40                  1:34 PM                4:25 PM

# %%
OP_CARRIER_unique_values
# Out:
# array(['9E', 'MQ', 'B6', 'WN', 'UA'], dtype=object)

# %%
test_data.columns
# Out:
# Index(['Date', 'CarrierCode', 'FlightNumber', 'Origin', 'Dest', 'clouds_des',
#        'temp_des', 'max_temp_des', 'min_temp_des', 'wind_dir_des',
#        'wind_spd_des', 'wind_gust_spd_des', 'snow_rate_des', 'snow_depth_des',
#        'precip_rate_des', 'pres_des', 'uv_des', 'dewpt_des', 'rh_des',
#        'slp_des', 'Scheduled departure time', 'Scheduled Arrival Time'],
#       dtype='object')

# %%
test_data.drop(columns=['Dest', 'max_temp_des', 'min_temp_des', 'snow_depth_des'],inplace=True)
test_data.head()
# Out:
#       Date CarrierCode  FlightNumber Origin  clouds_des  temp_des  \
# 0  4/19/24          UA           538    ORD          84     12.40
# 1  4/19/24          MQ          3402    ORD          84     12.40
# 2  4/19/24          B6           116    JFK          84     12.40
# 3  4/19/24          9E          5340    JFK          84     12.40
# 4  4/19/24          WN           491    MCO          84     12.40
#
#    wind_dir_des  wind_spd_des  wind_gust_spd_des  snow_rate_des  \
# 0           171          4.20               4.60              0
# 1           171          4.20               4.60              0
# 2           171          4.20               4.60              0
# 3           171          4.20               4.60              0
# 4           171          4.20               4.60              0
#
#    precip_rate_des  pres_des  uv_des  dewpt_des  rh_des  slp_des  \
# 0            42.56  1,003.50    8.30       3.90      57 1,019.50
# 1            42.56  1,003.50    8.30       3.90      57 1,019.50
# 2            42.56  1,003.50    8.30       3.90      57 1,019.50
# 3            42.56  1,003.50    8.30       3.90      57 1,019.50
# 4            42.56  1,003.50    8.30       3.90      57 1,019.50
#
#   Scheduled departure time Scheduled Arrival Time
# 0                  6:52 PM                9:47 PM
# 1                  7:59 PM               10:52 PM
# 2                  1:34 PM                2:51 PM
# 3                  2:55 PM                4:21 PM
# 4                 11:35 AM                2:20 PM

# %%
test_data['Date'] = pd.to_datetime(test_data['Date'])
# Out:
# /var/folders/kv/s4mg_r2n60q37wmj416xrvl40000gn/T/ipykernel_79385/461981124.py:1: UserWarning:
#
# Could not infer format, so each element will be parsed individually, falling back to `dateutil`. To ensure parsing is consistent and as-expected, please specify a format.

# %%
test_data.dtypes
# Out:
# Date                        datetime64[ns]
# CarrierCode                         object
# FlightNumber                         int64
# Origin                              object
# clouds_des                           int64
# temp_des                           float64
# wind_dir_des                         int64
# wind_spd_des                       float64
# wind_gust_spd_des                  float64
# snow_rate_des                        int64
# precip_rate_des                    float64
# pres_des                           float64
# uv_des                             float64
# dewpt_des                          float64
# rh_des                               int64
# slp_des                            float64
# Scheduled departure time            object
# Scheduled Arrival Time              object
# dtype: object

# %%
pred_ORD = test_data[test_data['Origin'] == 'ORD']
pred_JFK = test_data[test_data['Origin'] == 'JFK']
pred_MCO = test_data[test_data['Origin'] == 'MCO']

# %%
pred_ORD
# Out:
#          Date CarrierCode  FlightNumber Origin  clouds_des  temp_des  \
# 0  2024-04-19          UA           538    ORD          84     12.40
# 1  2024-04-19          MQ          3402    ORD          84     12.40
# 6  2024-04-20          UA           538    ORD          49     10.10
# 7  2024-04-20          MQ          3402    ORD          49     10.10
# 11 2024-04-21          UA           538    ORD          90     12.20
# 12 2024-04-21          MQ          3402    ORD          90     12.20
# 17 2024-04-22          UA           538    ORD          72     12.40
# 18 2024-04-22          MQ          3402    ORD          72     12.40
#
#     wind_dir_des  wind_spd_des  wind_gust_spd_des  snow_rate_des  \
# 0            171          4.20               4.60              0
# 1            171          4.20               4.60              0
# 6            227          3.40               6.50              0
# 7            227          3.40               6.50              0
# 11           110          1.90               2.70              0
# 12           110          1.90               2.70              0
# 17           131          5.50              10.90              0
# 18           131          5.50              10.90              0
#
#     precip_rate_des  pres_des  uv_des  dewpt_des  rh_des  slp_des  \
# 0             42.56  1,003.50    8.30       3.90      57 1,019.50
# 1             42.56  1,003.50    8.30       3.90      57 1,019.50
# 6             25.00  1,007.50    8.40       6.30      78 1,023.70
# 7             25.00  1,007.50    8.40       6.30      78 1,023.70
# 11            13.19  1,002.80    8.40       9.60      85 1,018.70
# 12            13.19  1,002.80    8.40       9.60      85 1,018.70
# 17            17.38    999.50    8.50       8.50      78 1,015.40
# 18            17.38    999.50    8.50       8.50      78 1,015.40
#
#    Scheduled departure time Scheduled Arrival Time
# 0                   6:52 PM                9:47 PM
# 1                   7:59 PM               10:52 PM
# 6                   6:52 PM                9:47 PM
# 7                   7:59 PM               10:52 PM
# 11                  6:52 PM                9:47 PM
# 12                  7:59 PM               10:52 PM
# 17                  6:52 PM                9:47 PM
# 18                  7:59 PM               10:52 PM

# %%
combined_df = pd.concat([pred_ORD, pred_JFK, pred_MCO], ignore_index=True)
combined_df.head()
# Out:
#         Date CarrierCode  FlightNumber Origin  clouds_des  temp_des  \
# 0 2024-04-19          UA           538    ORD          84     12.40
# 1 2024-04-19          MQ          3402    ORD          84     12.40
# 2 2024-04-20          UA           538    ORD          49     10.10
# 3 2024-04-20          MQ          3402    ORD          49     10.10
# 4 2024-04-21          UA           538    ORD          90     12.20
#
#    wind_dir_des  wind_spd_des  wind_gust_spd_des  snow_rate_des  \
# 0           171          4.20               4.60              0
# 1           171          4.20               4.60              0
# 2           227          3.40               6.50              0
# 3           227          3.40               6.50              0
# 4           110          1.90               2.70              0
#
#    precip_rate_des  pres_des  uv_des  dewpt_des  rh_des  slp_des  \
# 0            42.56  1,003.50    8.30       3.90      57 1,019.50
# 1            42.56  1,003.50    8.30       3.90      57 1,019.50
# 2            25.00  1,007.50    8.40       6.30      78 1,023.70
# 3            25.00  1,007.50    8.40       6.30      78 1,023.70
# 4            13.19  1,002.80    8.40       9.60      85 1,018.70
#
#   Scheduled departure time Scheduled Arrival Time
# 0                  6:52 PM                9:47 PM
# 1                  7:59 PM               10:52 PM
# 2                  6:52 PM                9:47 PM
# 3                  7:59 PM               10:52 PM
# 4                  6:52 PM                9:47 PM

# %%
combined_df
# Out:
#          Date CarrierCode  FlightNumber Origin  clouds_des  temp_des  \
# 0  2024-04-19          UA           538    ORD          84     12.40
# 1  2024-04-19          MQ          3402    ORD          84     12.40
# 2  2024-04-20          UA           538    ORD          49     10.10
# 3  2024-04-20          MQ          3402    ORD          49     10.10
# 4  2024-04-21          UA           538    ORD          90     12.20
# 5  2024-04-21          MQ          3402    ORD          90     12.20
# 6  2024-04-22          UA           538    ORD          72     12.40
# 7  2024-04-22          MQ          3402    ORD          72     12.40
# 8  2024-04-19          B6           116    JFK          84     12.40
# 9  2024-04-19          9E          5340    JFK          84     12.40
# 10 2024-04-20          B6           116    JFK          49     10.10
# 11 2024-04-20          9E          5340    JFK          49     10.10
# 12 2024-04-21          B6           116    JFK          90     12.20
# 13 2024-04-21          9E          5340    JFK          90     12.20
# 14 2024-04-22          B6           116    JFK          72     12.40
# 15 2024-04-22          9E          5340    JFK          72     12.40
# 16 2024-04-19          WN           491    MCO          84     12.40
# 17 2024-04-19          B6            56    MCO          84     12.40
# 18 2024-04-20          B6            56    MCO          49     10.10
# 19 2024-04-21          WN           491    MCO          90     12.20
# 20 2024-04-21          B6            56    MCO          90     12.20
# 21 2024-04-22          WN           491    MCO          72     12.40
# 22 2024-04-22          B6            56    MCO          72     12.40
#
#     wind_dir_des  wind_spd_des  wind_gust_spd_des  snow_rate_des  \
# 0            171          4.20               4.60              0
# 1            171          4.20               4.60              0
# 2            227          3.40               6.50              0
# 3            227          3.40               6.50              0
# 4            110          1.90               2.70              0
# 5            110          1.90               2.70              0
# 6            131          5.50              10.90              0
# 7            131          5.50              10.90              0
# 8            171          4.20               4.60              0
# 9            171          4.20               4.60              0
# 10           227          3.40               6.50              0
# 11           227          3.40               6.50              0
# 12           110          1.90               2.70              0
# 13           110          1.90               2.70              0
# 14           131          5.50              10.90              0
# 15           131          5.50              10.90              0
# 16           171          4.20               4.60              0
# 17           171          4.20               4.60              0
# 18           227          3.40               6.50              0
# 19           110          1.90               2.70              0
# 20           110          1.90               2.70              0
# 21           131          5.50              10.90              0
# 22           131          5.50              10.90              0
#
#     precip_rate_des  pres_des  uv_des  dewpt_des  rh_des  slp_des  \
# 0             42.56  1,003.50    8.30       3.90      57 1,019.50
# 1             42.56  1,003.50    8.30       3.90      57 1,019.50
# 2             25.00  1,007.50    8.40       6.30      78 1,023.70
# 3             25.00  1,007.50    8.40       6.30      78 1,023.70
# 4             13.19  1,002.80    8.40       9.60      85 1,018.70
# 5             13.19  1,002.80    8.40       9.60      85 1,018.70
# 6             17.38    999.50    8.50       8.50      78 1,015.40
# 7             17.38    999.50    8.50       8.50      78 1,015.40
# 8             42.56  1,003.50    8.30       3.90      57 1,019.50
# 9             42.56  1,003.50    8.30       3.90      57 1,019.50
# 10            25.00  1,007.50    8.40       6.30      78 1,023.70
# 11            25.00  1,007.50    8.40       6.30      78 1,023.70
# 12            13.19  1,002.80    8.40       9.60      85 1,018.70
# 13            13.19  1,002.80    8.40       9.60      85 1,018.70
# 14            17.38    999.50    8.50       8.50      78 1,015.40
# 15            17.38    999.50    8.50       8.50      78 1,015.40
# 16            42.56  1,003.50    8.30       3.90      57 1,019.50
# 17            42.56  1,003.50    8.30       3.90      57 1,019.50
# 18            25.00  1,007.50    8.40       6.30      78 1,023.70
# 19            13.19  1,002.80    8.40       9.60      85 1,018.70
# 20            13.19  1,002.80    8.40       9.60      85 1,018.70
# 21            17.38    999.50    8.50       8.50      78 1,015.40
# 22            17.38    999.50    8.50       8.50      78 1,015.40
#
#    Scheduled departure time Scheduled Arrival Time
# 0                   6:52 PM                9:47 PM
# 1                   7:59 PM               10:52 PM
# 2                   6:52 PM                9:47 PM
# 3                   7:59 PM               10:52 PM
# 4                   6:52 PM                9:47 PM
# 5                   7:59 PM               10:52 PM
# 6                   6:52 PM                9:47 PM
# 7                   7:59 PM               10:52 PM
# 8                   1:34 PM                2:51 PM
# 9                   2:55 PM                4:21 PM
# 10                  1:25 PM                2:41 PM
# 11                  2:55 PM                4:21 PM
# 12                  1:35 PM                2:51 PM
# 13                  2:55 PM                4:21 PM
# 14                  1:35 PM                2:51 PM
# 15                  2:55 PM                4:21 PM
# 16                 11:35 AM                2:20 PM
# 17                  1:35 PM                4:25 PM
# 18                  1:35 PM                4:25 PM
# 19                 11:05 AM                1:50 PM
# 20                  1:35 PM                4:25 PM
# 21                 11:35 AM                2:20 PM
# 22                  1:34 PM                4:25 PM

# %%
combined_df['Scheduled Arrival Hour']= pd.to_datetime(combined_df['Scheduled Arrival Time']).dt.hour
combined_df['Scheduled Arrival Minutes']= pd.to_datetime(combined_df['Scheduled Arrival Time']).dt.minute

combined_df['Scheduled departure Hour']= pd.to_datetime(combined_df['Scheduled departure time']).dt.hour
combined_df['Scheduled departure Minutes']= pd.to_datetime(combined_df['Scheduled departure time']).dt.minute

combined_df.head()
# Out:
# /var/folders/kv/s4mg_r2n60q37wmj416xrvl40000gn/T/ipykernel_79385/1372281680.py:1: UserWarning:
#
# Could not infer format, so each element will be parsed individually, falling back to `dateutil`. To ensure parsing is consistent and as-expected, please specify a format.
#
# /var/folders/kv/s4mg_r2n60q37wmj416xrvl40000gn/T/ipykernel_79385/1372281680.py:2: UserWarning:
#
# Could not infer format, so each element will be parsed individually, falling back to `dateutil`. To ensure parsing is consistent and as-expected, please specify a format.
#
# /var/folders/kv/s4mg_r2n60q37wmj416xrvl40000gn/T/ipykernel_79385/1372281680.py:4: UserWarning:
#
# Could not infer format, so each element will be parsed individually, falling back to `dateutil`. To ensure parsing is consistent and as-expected, please specify a format.
#
# /var/folders/kv/s4mg_r2n60q37wmj416xrvl40000gn/T/ipykernel_79385/1372281680.py:5: UserWarning:
#
# Could not infer format, so each element will be parsed individually, falling back to `dateutil`. To ensure parsing is consistent and as-expected, please specify a format.
#         Date CarrierCode  FlightNumber Origin  clouds_des  temp_des  \
# 0 2024-04-19          UA           538    ORD          84     12.40
# 1 2024-04-19          MQ          3402    ORD          84     12.40
# 2 2024-04-20          UA           538    ORD          49     10.10
# 3 2024-04-20          MQ          3402    ORD          49     10.10
# 4 2024-04-21          UA           538    ORD          90     12.20
#
#    wind_dir_des  wind_spd_des  wind_gust_spd_des  snow_rate_des  \
# 0           171          4.20               4.60              0
# 1           171          4.20               4.60              0
# 2           227          3.40               6.50              0
# 3           227          3.40               6.50              0
# 4           110          1.90               2.70              0
#
#    precip_rate_des  pres_des  uv_des  dewpt_des  rh_des  slp_des  \
# 0            42.56  1,003.50    8.30       3.90      57 1,019.50
# 1            42.56  1,003.50    8.30       3.90      57 1,019.50
# 2            25.00  1,007.50    8.40       6.30      78 1,023.70
# 3            25.00  1,007.50    8.40       6.30      78 1,023.70
# 4            13.19  1,002.80    8.40       9.60      85 1,018.70
#
#   Scheduled departure time Scheduled Arrival Time  Scheduled Arrival Hour  \
# 0                  6:52 PM                9:47 PM                      21
# 1                  7:59 PM               10:52 PM                      22
# 2                  6:52 PM                9:47 PM                      21
# 3                  7:59 PM               10:52 PM                      22
# 4                  6:52 PM                9:47 PM                      21
#
#    Scheduled Arrival Minutes  Scheduled departure Hour  \
# 0                         47                        18
# 1                         52                        19
# 2                         47                        18
# 3                         52                        19
# 4                         47                        18
#
#    Scheduled departure Minutes
# 0                           52
# 1                           59
# 2                           52
# 3                           59
# 4                           52

# %%
combined_df.rename(columns={'Origin': 'Origin Airport'}, inplace=True)
combined_df.rename(columns={'CarrierCode': 'Carrier Code'}, inplace=True)
combined_df.rename(columns={'FlightNumber': 'Flight Number'}, inplace=True)
combined_df.drop(columns=['Date', 'Scheduled departure time', 'Scheduled Arrival Time'], inplace=True)
combined_df.head()
# Out:
#   Carrier Code  Flight Number Origin Airport  clouds_des  temp_des  \
# 0           UA            538            ORD          84     12.40
# 1           MQ           3402            ORD          84     12.40
# 2           UA            538            ORD          49     10.10
# 3           MQ           3402            ORD          49     10.10
# 4           UA            538            ORD          90     12.20
#
#    wind_dir_des  wind_spd_des  wind_gust_spd_des  snow_rate_des  \
# 0           171          4.20               4.60              0
# 1           171          4.20               4.60              0
# 2           227          3.40               6.50              0
# 3           227          3.40               6.50              0
# 4           110          1.90               2.70              0
#
#    precip_rate_des  pres_des  uv_des  dewpt_des  rh_des  slp_des  \
# 0            42.56  1,003.50    8.30       3.90      57 1,019.50
# 1            42.56  1,003.50    8.30       3.90      57 1,019.50
# 2            25.00  1,007.50    8.40       6.30      78 1,023.70
# 3            25.00  1,007.50    8.40       6.30      78 1,023.70
# 4            13.19  1,002.80    8.40       9.60      85 1,018.70
#
#    Scheduled Arrival Hour  Scheduled Arrival Minutes  \
# 0                      21                         47
# 1                      22                         52
# 2                      21                         47
# 3                      22                         52
# 4                      21                         47
#
#    Scheduled departure Hour  Scheduled departure Minutes
# 0                        18                           52
# 1                        19                           59
# 2                        18                           52
# 3                        19                           59
# 4                        18                           52

# %%
combined_df = pd.get_dummies(combined_df, drop_first = True)
combined_df
# Out:
#     Flight Number  clouds_des  temp_des  wind_dir_des  wind_spd_des  \
# 0             538          84     12.40           171          4.20
# 1            3402          84     12.40           171          4.20
# 2             538          49     10.10           227          3.40
# 3            3402          49     10.10           227          3.40
# 4             538          90     12.20           110          1.90
# 5            3402          90     12.20           110          1.90
# 6             538          72     12.40           131          5.50
# 7            3402          72     12.40           131          5.50
# 8             116          84     12.40           171          4.20
# 9            5340          84     12.40           171          4.20
# 10            116          49     10.10           227          3.40
# 11           5340          49     10.10           227          3.40
# 12            116          90     12.20           110          1.90
# 13           5340          90     12.20           110          1.90
# 14            116          72     12.40           131          5.50
# 15           5340          72     12.40           131          5.50
# 16            491          84     12.40           171          4.20
# 17             56          84     12.40           171          4.20
# 18             56          49     10.10           227          3.40
# 19            491          90     12.20           110          1.90
# 20             56          90     12.20           110          1.90
# 21            491          72     12.40           131          5.50
# 22             56          72     12.40           131          5.50
#
#     wind_gust_spd_des  snow_rate_des  precip_rate_des  pres_des  uv_des  \
# 0                4.60              0            42.56  1,003.50    8.30
# 1                4.60              0            42.56  1,003.50    8.30
# 2                6.50              0            25.00  1,007.50    8.40
# 3                6.50              0            25.00  1,007.50    8.40
# 4                2.70              0            13.19  1,002.80    8.40
# 5                2.70              0            13.19  1,002.80    8.40
# 6               10.90              0            17.38    999.50    8.50
# 7               10.90              0            17.38    999.50    8.50
# 8                4.60              0            42.56  1,003.50    8.30
# 9                4.60              0            42.56  1,003.50    8.30
# 10               6.50              0            25.00  1,007.50    8.40
# 11               6.50              0            25.00  1,007.50    8.40
# 12               2.70              0            13.19  1,002.80    8.40
# 13               2.70              0            13.19  1,002.80    8.40
# 14              10.90              0            17.38    999.50    8.50
# 15              10.90              0            17.38    999.50    8.50
# 16               4.60              0            42.56  1,003.50    8.30
# 17               4.60              0            42.56  1,003.50    8.30
# 18               6.50              0            25.00  1,007.50    8.40
# 19               2.70              0            13.19  1,002.80    8.40
# 20               2.70              0            13.19  1,002.80    8.40
# 21              10.90              0            17.38    999.50    8.50
# 22              10.90              0            17.38    999.50    8.50
#
#     dewpt_des  rh_des  slp_des  Scheduled Arrival Hour  \
# 0        3.90      57 1,019.50                      21
# 1        3.90      57 1,019.50                      22
# 2        6.30      78 1,023.70                      21
# 3        6.30      78 1,023.70                      22
# 4        9.60      85 1,018.70                      21
# 5        9.60      85 1,018.70                      22
# 6        8.50      78 1,015.40                      21
# 7        8.50      78 1,015.40                      22
# 8        3.90      57 1,019.50                      14
# 9        3.90      57 1,019.50                      16
# 10       6.30      78 1,023.70                      14
# 11       6.30      78 1,023.70                      16
# 12       9.60      85 1,018.70                      14
# 13       9.60      85 1,018.70                      16
# 14       8.50      78 1,015.40                      14
# 15       8.50      78 1,015.40                      16
# 16       3.90      57 1,019.50                      14
# 17       3.90      57 1,019.50                      16
# 18       6.30      78 1,023.70                      16
# 19       9.60      85 1,018.70                      13
# 20       9.60      85 1,018.70                      16
# 21       8.50      78 1,015.40                      14
# 22       8.50      78 1,015.40                      16
#
#     Scheduled Arrival Minutes  Scheduled departure Hour  \
# 0                          47                        18
# 1                          52                        19
# 2                          47                        18
# 3                          52                        19
# 4                          47                        18
# 5                          52                        19
# 6                          47                        18
# 7                          52                        19
# 8                          51                        13
# 9                          21                        14
# 10                         41                        13
# 11                         21                        14
# 12                         51                        13
# 13                         21                        14
# 14                         51                        13
# 15                         21                        14
# 16                         20                        11
# 17                         25                        13
# 18                         25                        13
# 19                         50                        11
# 20                         25                        13
# 21                         20                        11
# 22                         25                        13
#
#     Scheduled departure Minutes  Carrier Code_B6  Carrier Code_MQ  \
# 0                            52            False            False
# 1                            59            False             True
# 2                            52            False            False
# 3                            59            False             True
# 4                            52            False            False
# 5                            59            False             True
# 6                            52            False            False
# 7                            59            False             True
# 8                            34             True            False
# 9                            55            False            False
# 10                           25             True            False
# 11                           55            False            False
# 12                           35             True            False
# 13                           55            False            False
# 14                           35             True            False
# 15                           55            False            False
# 16                           35            False            False
# 17                           35             True            False
# 18                           35             True            False
# 19                            5            False            False
# 20                           35             True            False
# 21                           35            False            False
# 22                           34             True            False
#
#     Carrier Code_UA  Carrier Code_WN  Origin Airport_MCO  Origin Airport_ORD
# 0              True            False               False                True
# 1             False            False               False                True
# 2              True            False               False                True
# 3             False            False               False                True
# 4              True            False               False                True
# 5             False            False               False                True
# 6              True            False               False                True
# 7             False            False               False                True
# 8             False            False               False               False
# 9             False            False               False               False
# 10            False            False               False               False
# 11            False            False               False               False
# 12            False            False               False               False
# 13            False            False               False               False
# 14            False            False               False               False
# 15            False            False               False               False
# 16            False             True                True               False
# 17            False            False                True               False
# 18            False            False                True               False
# 19            False             True                True               False
# 20            False            False                True               False
# 21            False             True                True               False
# 22            False            False                True               False

# %%
#Ensuring the test dataset has the same dummy columns as the training dataset
# combined_pred = pd.get_dummies(combined_pred)
missing_cols = set(X_train.columns) - set(combined_df.columns)
for c in missing_cols:
    combined_df[c] = 0
combined_df = combined_df[X_train.columns]

# %%
if True: 
    from sklearn.preprocessing import StandardScaler
    sc = StandardScaler()
    combined_df = pd.DataFrame(sc.fit_transform(combined_df), columns = combined_df.columns, index = combined_df.index)
combined_df
# Out:
#     Flight Number  clouds_des  dewpt_des  precip_rate_des  pres_des  rh_des  \
# 0           -0.57        0.61      -1.44             1.57      0.13   -1.62
# 1            0.83        0.61      -1.44             1.57      0.13   -1.62
# 2           -0.57       -1.71      -0.36             0.04      1.57    0.34
# 3            0.83       -1.71      -0.36             0.04      1.57    0.34
# 4           -0.57        1.00       1.12            -0.99     -0.12    1.00
# 5            0.83        1.00       1.12            -0.99     -0.12    1.00
# 6           -0.57       -0.19       0.63            -0.62     -1.32    0.34
# 7            0.83       -0.19       0.63            -0.62     -1.32    0.34
# 8           -0.78        0.61      -1.44             1.57      0.13   -1.62
# 9            1.79        0.61      -1.44             1.57      0.13   -1.62
# 10          -0.78       -1.71      -0.36             0.04      1.57    0.34
# 11           1.79       -1.71      -0.36             0.04      1.57    0.34
# 12          -0.78        1.00       1.12            -0.99     -0.12    1.00
# 13           1.79        1.00       1.12            -0.99     -0.12    1.00
# 14          -0.78       -0.19       0.63            -0.62     -1.32    0.34
# 15           1.79       -0.19       0.63            -0.62     -1.32    0.34
# 16          -0.60        0.61      -1.44             1.57      0.13   -1.62
# 17          -0.81        0.61      -1.44             1.57      0.13   -1.62
# 18          -0.81       -1.71      -0.36             0.04      1.57    0.34
# 19          -0.60        1.00       1.12            -0.99     -0.12    1.00
# 20          -0.81        1.00       1.12            -0.99     -0.12    1.00
# 21          -0.60       -0.19       0.63            -0.62     -1.32    0.34
# 22          -0.81       -0.19       0.63            -0.62     -1.32    0.34
#
#     slp_des  snow_rate_des  temp_des  uv_des  wind_dir_des  wind_gust_spd_des  \
# 0      0.13           0.00      0.60   -1.38          0.33              -0.50
# 1      0.13           0.00      0.60   -1.38          0.33              -0.50
# 2      1.59           0.00     -1.89   -0.00          1.62               0.11
# 3      1.59           0.00     -1.89   -0.00          1.62               0.11
# 4     -0.15           0.00      0.38   -0.00         -1.08              -1.11
# 5     -0.15           0.00      0.38   -0.00         -1.08              -1.11
# 6     -1.30           0.00      0.60    1.38         -0.60               1.53
# 7     -1.30           0.00      0.60    1.38         -0.60               1.53
# 8      0.13           0.00      0.60   -1.38          0.33              -0.50
# 9      0.13           0.00      0.60   -1.38          0.33              -0.50
# 10     1.59           0.00     -1.89   -0.00          1.62               0.11
# 11     1.59           0.00     -1.89   -0.00          1.62               0.11
# 12    -0.15           0.00      0.38   -0.00         -1.08              -1.11
# 13    -0.15           0.00      0.38   -0.00         -1.08              -1.11
# 14    -1.30           0.00      0.60    1.38         -0.60               1.53
# 15    -1.30           0.00      0.60    1.38         -0.60               1.53
# 16     0.13           0.00      0.60   -1.38          0.33              -0.50
# 17     0.13           0.00      0.60   -1.38          0.33              -0.50
# 18     1.59           0.00     -1.89   -0.00          1.62               0.11
# 19    -0.15           0.00      0.38   -0.00         -1.08              -1.11
# 20    -0.15           0.00      0.38   -0.00         -1.08              -1.11
# 21    -1.30           0.00      0.60    1.38         -0.60               1.53
# 22    -1.30           0.00      0.60    1.38         -0.60               1.53
#
#     wind_spd_des  Scheduled Arrival Hour  Scheduled Arrival Minutes  \
# 0           0.33                    1.16                       0.69
# 1           0.33                    1.47                       1.06
# 2          -0.27                    1.16                       0.69
# 3          -0.27                    1.47                       1.06
# 4          -1.40                    1.16                       0.69
# 5          -1.40                    1.47                       1.06
# 6           1.30                    1.16                       0.69
# 7           1.30                    1.47                       1.06
# 8           0.33                   -1.01                       0.99
# 9           0.33                   -0.39                      -1.22
# 10         -0.27                   -1.01                       0.25
# 11         -0.27                   -0.39                      -1.22
# 12         -1.40                   -1.01                       0.99
# 13         -1.40                   -0.39                      -1.22
# 14          1.30                   -1.01                       0.99
# 15          1.30                   -0.39                      -1.22
# 16          0.33                   -1.01                      -1.29
# 17          0.33                   -0.39                      -0.93
# 18         -0.27                   -0.39                      -0.93
# 19         -1.40                   -1.32                       0.92
# 20         -1.40                   -0.39                      -0.93
# 21          1.30                   -1.01                      -1.29
# 22          1.30                   -0.39                      -0.93
#
#     Scheduled departure Hour  Scheduled departure Minutes  Carrier Code_B6  \
# 0                       1.12                         0.60            -0.73
# 1                       1.48                         1.11            -0.73
# 2                       1.12                         0.60            -0.73
# 3                       1.48                         1.11            -0.73
# 4                       1.12                         0.60            -0.73
# 5                       1.48                         1.11            -0.73
# 6                       1.12                         0.60            -0.73
# 7                       1.48                         1.11            -0.73
# 8                      -0.65                        -0.72             1.37
# 9                      -0.29                         0.82            -0.73
# 10                     -0.65                        -1.38             1.37
# 11                     -0.29                         0.82            -0.73
# 12                     -0.65                        -0.64             1.37
# 13                     -0.29                         0.82            -0.73
# 14                     -0.65                        -0.64             1.37
# 15                     -0.29                         0.82            -0.73
# 16                     -1.36                        -0.64            -0.73
# 17                     -0.65                        -0.64             1.37
# 18                     -0.65                        -0.64             1.37
# 19                     -1.36                        -2.84            -0.73
# 20                     -0.65                        -0.64             1.37
# 21                     -1.36                        -0.64            -0.73
# 22                     -0.65                        -0.72             1.37
#
#     Carrier Code_MQ  Carrier Code_UA  Carrier Code_WN  Origin Airport_MCO  \
# 0             -0.46             2.18            -0.39               -0.66
# 1              2.18            -0.46            -0.39               -0.66
# 2             -0.46             2.18            -0.39               -0.66
# 3              2.18            -0.46            -0.39               -0.66
# 4             -0.46             2.18            -0.39               -0.66
# 5              2.18            -0.46            -0.39               -0.66
# 6             -0.46             2.18            -0.39               -0.66
# 7              2.18            -0.46            -0.39               -0.66
# 8             -0.46            -0.46            -0.39               -0.66
# 9             -0.46            -0.46            -0.39               -0.66
# 10            -0.46            -0.46            -0.39               -0.66
# 11            -0.46            -0.46            -0.39               -0.66
# 12            -0.46            -0.46            -0.39               -0.66
# 13            -0.46            -0.46            -0.39               -0.66
# 14            -0.46            -0.46            -0.39               -0.66
# 15            -0.46            -0.46            -0.39               -0.66
# 16            -0.46            -0.46             2.58                1.51
# 17            -0.46            -0.46            -0.39                1.51
# 18            -0.46            -0.46            -0.39                1.51
# 19            -0.46            -0.46             2.58                1.51
# 20            -0.46            -0.46            -0.39                1.51
# 21            -0.46            -0.46             2.58                1.51
# 22            -0.46            -0.46            -0.39                1.51
#
#     Origin Airport_ORD
# 0                 1.37
# 1                 1.37
# 2                 1.37
# 3                 1.37
# 4                 1.37
# 5                 1.37
# 6                 1.37
# 7                 1.37
# 8                -0.73
# 9                -0.73
# 10               -0.73
# 11               -0.73
# 12               -0.73
# 13               -0.73
# 14               -0.73
# 15               -0.73
# 16               -0.73
# 17               -0.73
# 18               -0.73
# 19               -0.73
# 20               -0.73
# 21               -0.73
# 22               -0.73

# %%
# Predict the labels for the test data
y_pred_test = rf_1.predict(combined_df) 
status_mapping = {0: 'Early', 1: 'Late', 2: 'On-time'}
y_pred_labels = [status_mapping[pred] for pred in y_pred_test]
# Print each label with its corresponding index
for index, label in enumerate(y_pred_labels):
    print(f"Index {index}: {label}")
# Out:
# Index 0: Early
# Index 1: Early
# Index 2: Early
# Index 3: Early
# Index 4: Early
# Index 5: Early
# Index 6: Early
# Index 7: Early
# Index 8: Early
# Index 9: Early
# Index 10: Late
# Index 11: Early
# Index 12: Early
# Index 13: Early
# Index 14: Early
# Index 15: Early
# Index 16: Early
# Index 17: Early
# Index 18: Late
# Index 19: Early
# Index 20: Late
# Index 21: Early
# Index 22: Early

# %%
def calculate_previous_flight_status(group):
    # Check if date is the same within the group, shift by 1 to compare with previous row
    group['Previous Flight Status'] = group['Date'].eq(group['Date'].shift(1))
    return group

# %%
pred_ORD
# Out:
#          Date CarrierCode  FlightNumber Origin  clouds_des  temp_des  \
# 0  2024-04-19          UA           538    ORD          84     12.40
# 1  2024-04-19          MQ          3402    ORD          84     12.40
# 6  2024-04-20          UA           538    ORD          49     10.10
# 7  2024-04-20          MQ          3402    ORD          49     10.10
# 11 2024-04-21          UA           538    ORD          90     12.20
# 12 2024-04-21          MQ          3402    ORD          90     12.20
# 17 2024-04-22          UA           538    ORD          72     12.40
# 18 2024-04-22          MQ          3402    ORD          72     12.40
#
#     wind_dir_des  wind_spd_des  wind_gust_spd_des  snow_rate_des  \
# 0            171          4.20               4.60              0
# 1            171          4.20               4.60              0
# 6            227          3.40               6.50              0
# 7            227          3.40               6.50              0
# 11           110          1.90               2.70              0
# 12           110          1.90               2.70              0
# 17           131          5.50              10.90              0
# 18           131          5.50              10.90              0
#
#     precip_rate_des  pres_des  uv_des  dewpt_des  rh_des  slp_des  \
# 0             42.56  1,003.50    8.30       3.90      57 1,019.50
# 1             42.56  1,003.50    8.30       3.90      57 1,019.50
# 6             25.00  1,007.50    8.40       6.30      78 1,023.70
# 7             25.00  1,007.50    8.40       6.30      78 1,023.70
# 11            13.19  1,002.80    8.40       9.60      85 1,018.70
# 12            13.19  1,002.80    8.40       9.60      85 1,018.70
# 17            17.38    999.50    8.50       8.50      78 1,015.40
# 18            17.38    999.50    8.50       8.50      78 1,015.40
#
#    Scheduled departure time Scheduled Arrival Time
# 0                   6:52 PM                9:47 PM
# 1                   7:59 PM               10:52 PM
# 6                   6:52 PM                9:47 PM
# 7                   7:59 PM               10:52 PM
# 11                  6:52 PM                9:47 PM
# 12                  7:59 PM               10:52 PM
# 17                  6:52 PM                9:47 PM
# 18                  7:59 PM               10:52 PM

# %%
#filtering the data and setting previous flight status
pred_ORD.sort_values(by=['Date','Scheduled Arrival Time'])
pred_ORD = pred_ORD.groupby(["Date"]).apply(calculate_previous_flight_status)
# pred_ORD.dropna(subset=["Previous Flight Status"], inplace=True)


pred_JFK.sort_values(by=['Date','Scheduled Arrival Time'], inplace=True)
pred_JFK = pred_JFK.groupby(["Date"]).apply(calculate_previous_flight_status)
# pred_JFK.dropna(subset=["Previous Flight Status"], inplace=True)


pred_MCO.sort_values(by=['Date','Scheduled Arrival Time'], inplace=True)
pred_MCO = pred_MCO.groupby(["Date"]).apply(calculate_previous_flight_status)
# pred_MCO.dropna(subset=["Previous Flight Status"], inplace=True)

pred_ORD = pred_ORD[pred_ORD['Previous Flight Status']]
pred_JFK = pred_JFK[pred_JFK['Previous Flight Status']]
pred_MCO = pred_MCO[pred_MCO['Previous Flight Status']]

pred_MCO.isna().sum()
pred_JFK.isna().sum()
pred_ORD.isna().sum()
# Out:
#          Date CarrierCode  FlightNumber Origin  clouds_des  temp_des  \
# 1  2024-04-19          MQ          3402    ORD          84     12.40
# 0  2024-04-19          UA           538    ORD          84     12.40
# 7  2024-04-20          MQ          3402    ORD          49     10.10
# 6  2024-04-20          UA           538    ORD          49     10.10
# 12 2024-04-21          MQ          3402    ORD          90     12.20
# 11 2024-04-21          UA           538    ORD          90     12.20
# 18 2024-04-22          MQ          3402    ORD          72     12.40
# 17 2024-04-22          UA           538    ORD          72     12.40
#
#     wind_dir_des  wind_spd_des  wind_gust_spd_des  snow_rate_des  \
# 1            171          4.20               4.60              0
# 0            171          4.20               4.60              0
# 7            227          3.40               6.50              0
# 6            227          3.40               6.50              0
# 12           110          1.90               2.70              0
# 11           110          1.90               2.70              0
# 18           131          5.50              10.90              0
# 17           131          5.50              10.90              0
#
#     precip_rate_des  pres_des  uv_des  dewpt_des  rh_des  slp_des  \
# 1             42.56  1,003.50    8.30       3.90      57 1,019.50
# 0             42.56  1,003.50    8.30       3.90      57 1,019.50
# 7             25.00  1,007.50    8.40       6.30      78 1,023.70
# 6             25.00  1,007.50    8.40       6.30      78 1,023.70
# 12            13.19  1,002.80    8.40       9.60      85 1,018.70
# 11            13.19  1,002.80    8.40       9.60      85 1,018.70
# 18            17.38    999.50    8.50       8.50      78 1,015.40
# 17            17.38    999.50    8.50       8.50      78 1,015.40
#
#    Scheduled departure time Scheduled Arrival Time
# 1                   7:59 PM               10:52 PM
# 0                   6:52 PM                9:47 PM
# 7                   7:59 PM               10:52 PM
# 6                   6:52 PM                9:47 PM
# 12                  7:59 PM               10:52 PM
# 11                  6:52 PM                9:47 PM
# 18                  7:59 PM               10:52 PM
# 17                  6:52 PM                9:47 PM
# /var/folders/kv/s4mg_r2n60q37wmj416xrvl40000gn/T/ipykernel_79385/630211676.py:7: SettingWithCopyWarning:
#
#
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
# /var/folders/kv/s4mg_r2n60q37wmj416xrvl40000gn/T/ipykernel_79385/630211676.py:12: SettingWithCopyWarning:
#
#
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# Date                        0
# CarrierCode                 0
# FlightNumber                0
# Origin                      0
# clouds_des                  0
# temp_des                    0
# wind_dir_des                0
# wind_spd_des                0
# wind_gust_spd_des           0
# snow_rate_des               0
# precip_rate_des             0
# pres_des                    0
# uv_des                      0
# dewpt_des                   0
# rh_des                      0
# slp_des                     0
# Scheduled departure time    0
# Scheduled Arrival Time      0
# Previous Flight Status      0
# dtype: int64
# Date                        0
# CarrierCode                 0
# FlightNumber                0
# Origin                      0
# clouds_des                  0
# temp_des                    0
# wind_dir_des                0
# wind_spd_des                0
# wind_gust_spd_des           0
# snow_rate_des               0
# precip_rate_des             0
# pres_des                    0
# uv_des                      0
# dewpt_des                   0
# rh_des                      0
# slp_des                     0
# Scheduled departure time    0
# Scheduled Arrival Time      0
# Previous Flight Status      0
# dtype: int64
# Date                        0
# CarrierCode                 0
# FlightNumber                0
# Origin                      0
# clouds_des                  0
# temp_des                    0
# wind_dir_des                0
# wind_spd_des                0
# wind_gust_spd_des           0
# snow_rate_des               0
# precip_rate_des             0
# pres_des                    0
# uv_des                      0
# dewpt_des                   0
# rh_des                      0
# slp_des                     0
# Scheduled departure time    0
# Scheduled Arrival Time      0
# Previous Flight Status      0
# dtype: int64

# %%
pred_ORD
# Out:
#                     Date CarrierCode  FlightNumber Origin  clouds_des  \
# Date
# 2024-04-19 1  2024-04-19          MQ          3402    ORD          84
# 2024-04-20 7  2024-04-20          MQ          3402    ORD          49
# 2024-04-21 12 2024-04-21          MQ          3402    ORD          90
# 2024-04-22 18 2024-04-22          MQ          3402    ORD          72
#
#                temp_des  wind_dir_des  wind_spd_des  wind_gust_spd_des  \
# Date
# 2024-04-19 1      12.40           171          4.20               4.60
# 2024-04-20 7      10.10           227          3.40               6.50
# 2024-04-21 12     12.20           110          1.90               2.70
# 2024-04-22 18     12.40           131          5.50              10.90
#
#                snow_rate_des  precip_rate_des  pres_des  uv_des  dewpt_des  \
# Date
# 2024-04-19 1               0            42.56  1,003.50    8.30       3.90
# 2024-04-20 7               0            25.00  1,007.50    8.40       6.30
# 2024-04-21 12              0            13.19  1,002.80    8.40       9.60
# 2024-04-22 18              0            17.38    999.50    8.50       8.50
#
#                rh_des  slp_des Scheduled departure time  \
# Date
# 2024-04-19 1       57 1,019.50                  7:59 PM
# 2024-04-20 7       78 1,023.70                  7:59 PM
# 2024-04-21 12      85 1,018.70                  7:59 PM
# 2024-04-22 18      78 1,015.40                  7:59 PM
#
#               Scheduled Arrival Time  Previous Flight Status
# Date
# 2024-04-19 1                10:52 PM                    True
# 2024-04-20 7                10:52 PM                    True
# 2024-04-21 12               10:52 PM                    True
# 2024-04-22 18               10:52 PM                    True

# %%
pred_JFK
# Out:
#                     Date CarrierCode  FlightNumber Origin  clouds_des  \
# Date
# 2024-04-19 3  2024-04-19          9E          5340    JFK          84
# 2024-04-20 9  2024-04-20          9E          5340    JFK          49
# 2024-04-21 14 2024-04-21          9E          5340    JFK          90
# 2024-04-22 20 2024-04-22          9E          5340    JFK          72
#
#                temp_des  wind_dir_des  wind_spd_des  wind_gust_spd_des  \
# Date
# 2024-04-19 3      12.40           171          4.20               4.60
# 2024-04-20 9      10.10           227          3.40               6.50
# 2024-04-21 14     12.20           110          1.90               2.70
# 2024-04-22 20     12.40           131          5.50              10.90
#
#                snow_rate_des  precip_rate_des  pres_des  uv_des  dewpt_des  \
# Date
# 2024-04-19 3               0            42.56  1,003.50    8.30       3.90
# 2024-04-20 9               0            25.00  1,007.50    8.40       6.30
# 2024-04-21 14              0            13.19  1,002.80    8.40       9.60
# 2024-04-22 20              0            17.38    999.50    8.50       8.50
#
#                rh_des  slp_des Scheduled departure time  \
# Date
# 2024-04-19 3       57 1,019.50                  2:55 PM
# 2024-04-20 9       78 1,023.70                  2:55 PM
# 2024-04-21 14      85 1,018.70                  2:55 PM
# 2024-04-22 20      78 1,015.40                  2:55 PM
#
#               Scheduled Arrival Time  Previous Flight Status
# Date
# 2024-04-19 3                 4:21 PM                    True
# 2024-04-20 9                 4:21 PM                    True
# 2024-04-21 14                4:21 PM                    True
# 2024-04-22 20                4:21 PM                    True

# %%
pred_MCO
# Out:
#                     Date CarrierCode  FlightNumber Origin  clouds_des  \
# Date
# 2024-04-19 5  2024-04-19          B6            56    MCO          84
# 2024-04-21 16 2024-04-21          B6            56    MCO          90
# 2024-04-22 22 2024-04-22          B6            56    MCO          72
#
#                temp_des  wind_dir_des  wind_spd_des  wind_gust_spd_des  \
# Date
# 2024-04-19 5      12.40           171          4.20               4.60
# 2024-04-21 16     12.20           110          1.90               2.70
# 2024-04-22 22     12.40           131          5.50              10.90
#
#                snow_rate_des  precip_rate_des  pres_des  uv_des  dewpt_des  \
# Date
# 2024-04-19 5               0            42.56  1,003.50    8.30       3.90
# 2024-04-21 16              0            13.19  1,002.80    8.40       9.60
# 2024-04-22 22              0            17.38    999.50    8.50       8.50
#
#                rh_des  slp_des Scheduled departure time  \
# Date
# 2024-04-19 5       57 1,019.50                  1:35 PM
# 2024-04-21 16      85 1,018.70                  1:35 PM
# 2024-04-22 22      78 1,015.40                  1:34 PM
#
#               Scheduled Arrival Time  Previous Flight Status
# Date
# 2024-04-19 5                 4:25 PM                    True
# 2024-04-21 16                4:25 PM                    True
# 2024-04-22 22                4:25 PM                    True

# %%
combined_df_prev = pd.concat([pred_ORD, pred_JFK, pred_MCO], ignore_index=True)

# %%
combined_df_prev
# Out:
#          Date CarrierCode  FlightNumber Origin  clouds_des  temp_des  \
# 0  2024-04-19          MQ          3402    ORD          84     12.40
# 1  2024-04-20          MQ          3402    ORD          49     10.10
# 2  2024-04-21          MQ          3402    ORD          90     12.20
# 3  2024-04-22          MQ          3402    ORD          72     12.40
# 4  2024-04-19          9E          5340    JFK          84     12.40
# 5  2024-04-20          9E          5340    JFK          49     10.10
# 6  2024-04-21          9E          5340    JFK          90     12.20
# 7  2024-04-22          9E          5340    JFK          72     12.40
# 8  2024-04-19          B6            56    MCO          84     12.40
# 9  2024-04-21          B6            56    MCO          90     12.20
# 10 2024-04-22          B6            56    MCO          72     12.40
#
#     wind_dir_des  wind_spd_des  wind_gust_spd_des  snow_rate_des  \
# 0            171          4.20               4.60              0
# 1            227          3.40               6.50              0
# 2            110          1.90               2.70              0
# 3            131          5.50              10.90              0
# 4            171          4.20               4.60              0
# 5            227          3.40               6.50              0
# 6            110          1.90               2.70              0
# 7            131          5.50              10.90              0
# 8            171          4.20               4.60              0
# 9            110          1.90               2.70              0
# 10           131          5.50              10.90              0
#
#     precip_rate_des  pres_des  uv_des  dewpt_des  rh_des  slp_des  \
# 0             42.56  1,003.50    8.30       3.90      57 1,019.50
# 1             25.00  1,007.50    8.40       6.30      78 1,023.70
# 2             13.19  1,002.80    8.40       9.60      85 1,018.70
# 3             17.38    999.50    8.50       8.50      78 1,015.40
# 4             42.56  1,003.50    8.30       3.90      57 1,019.50
# 5             25.00  1,007.50    8.40       6.30      78 1,023.70
# 6             13.19  1,002.80    8.40       9.60      85 1,018.70
# 7             17.38    999.50    8.50       8.50      78 1,015.40
# 8             42.56  1,003.50    8.30       3.90      57 1,019.50
# 9             13.19  1,002.80    8.40       9.60      85 1,018.70
# 10            17.38    999.50    8.50       8.50      78 1,015.40
#
#    Scheduled departure time Scheduled Arrival Time  Previous Flight Status
# 0                   7:59 PM               10:52 PM                    True
# 1                   7:59 PM               10:52 PM                    True
# 2                   7:59 PM               10:52 PM                    True
# 3                   7:59 PM               10:52 PM                    True
# 4                   2:55 PM                4:21 PM                    True
# 5                   2:55 PM                4:21 PM                    True
# 6                   2:55 PM                4:21 PM                    True
# 7                   2:55 PM                4:21 PM                    True
# 8                   1:35 PM                4:25 PM                    True
# 9                   1:35 PM                4:25 PM                    True
# 10                  1:34 PM                4:25 PM                    True

# %%
combined_df_prev['Scheduled Arrival Hour']= pd.to_datetime(combined_df_prev['Scheduled Arrival Time']).dt.hour
combined_df_prev['Scheduled Arrival Minutes']= pd.to_datetime(combined_df_prev['Scheduled Arrival Time']).dt.minute

combined_df_prev['Scheduled departure Hour']= pd.to_datetime(combined_df_prev['Scheduled departure time']).dt.hour
combined_df_prev['Scheduled departure Minutes']= pd.to_datetime(combined_df_prev['Scheduled departure time']).dt.minute

combined_df_prev.head()
# Out:
# /var/folders/kv/s4mg_r2n60q37wmj416xrvl40000gn/T/ipykernel_79385/1251015400.py:1: UserWarning:
#
# Could not infer format, so each element will be parsed individually, falling back to `dateutil`. To ensure parsing is consistent and as-expected, please specify a format.
#
# /var/folders/kv/s4mg_r2n60q37wmj416xrvl40000gn/T/ipykernel_79385/1251015400.py:2: UserWarning:
#
# Could not infer format, so each element will be parsed individually, falling back to `dateutil`. To ensure parsing is consistent and as-expected, please specify a format.
#
# /var/folders/kv/s4mg_r2n60q37wmj416xrvl40000gn/T/ipykernel_79385/1251015400.py:4: UserWarning:
#
# Could not infer format, so each element will be parsed individually, falling back to `dateutil`. To ensure parsing is consistent and as-expected, please specify a format.
#
# /var/folders/kv/s4mg_r2n60q37wmj416xrvl40000gn/T/ipykernel_79385/1251015400.py:5: UserWarning:
#
# Could not infer format, so each element will be parsed individually, falling back to `dateutil`. To ensure parsing is consistent and as-expected, please specify a format.
#         Date CarrierCode  FlightNumber Origin  clouds_des  temp_des  \
# 0 2024-04-19          MQ          3402    ORD          84     12.40
# 1 2024-04-20          MQ          3402    ORD          49     10.10
# 2 2024-04-21          MQ          3402    ORD          90     12.20
# 3 2024-04-22          MQ          3402    ORD          72     12.40
# 4 2024-04-19          9E          5340    JFK          84     12.40
#
#    wind_dir_des  wind_spd_des  wind_gust_spd_des  snow_rate_des  \
# 0           171          4.20               4.60              0
# 1           227          3.40               6.50              0
# 2           110          1.90               2.70              0
# 3           131          5.50              10.90              0
# 4           171          4.20               4.60              0
#
#    precip_rate_des  pres_des  uv_des  dewpt_des  rh_des  slp_des  \
# 0            42.56  1,003.50    8.30       3.90      57 1,019.50
# 1            25.00  1,007.50    8.40       6.30      78 1,023.70
# 2            13.19  1,002.80    8.40       9.60      85 1,018.70
# 3            17.38    999.50    8.50       8.50      78 1,015.40
# 4            42.56  1,003.50    8.30       3.90      57 1,019.50
#
#   Scheduled departure time Scheduled Arrival Time  Previous Flight Status  \
# 0                  7:59 PM               10:52 PM                    True
# 1                  7:59 PM               10:52 PM                    True
# 2                  7:59 PM               10:52 PM                    True
# 3                  7:59 PM               10:52 PM                    True
# 4                  2:55 PM                4:21 PM                    True
#
#    Scheduled Arrival Hour  Scheduled Arrival Minutes  \
# 0                      22                         52
# 1                      22                         52
# 2                      22                         52
# 3                      22                         52
# 4                      16                         21
#
#    Scheduled departure Hour  Scheduled departure Minutes
# 0                        19                           59
# 1                        19                           59
# 2                        19                           59
# 3                        19                           59
# 4                        14                           55

# %%
set(combined_df_prev['CarrierCode'])
# Out:
# {'9E', 'B6', 'MQ'}

# %%
combined_df_prev
# Out:
#          Date CarrierCode  FlightNumber Origin  clouds_des  temp_des  \
# 0  2024-04-19          MQ          3402    ORD          84     12.40
# 1  2024-04-20          MQ          3402    ORD          49     10.10
# 2  2024-04-21          MQ          3402    ORD          90     12.20
# 3  2024-04-22          MQ          3402    ORD          72     12.40
# 4  2024-04-19          9E          5340    JFK          84     12.40
# 5  2024-04-20          9E          5340    JFK          49     10.10
# 6  2024-04-21          9E          5340    JFK          90     12.20
# 7  2024-04-22          9E          5340    JFK          72     12.40
# 8  2024-04-19          B6            56    MCO          84     12.40
# 9  2024-04-21          B6            56    MCO          90     12.20
# 10 2024-04-22          B6            56    MCO          72     12.40
#
#     wind_dir_des  wind_spd_des  wind_gust_spd_des  snow_rate_des  \
# 0            171          4.20               4.60              0
# 1            227          3.40               6.50              0
# 2            110          1.90               2.70              0
# 3            131          5.50              10.90              0
# 4            171          4.20               4.60              0
# 5            227          3.40               6.50              0
# 6            110          1.90               2.70              0
# 7            131          5.50              10.90              0
# 8            171          4.20               4.60              0
# 9            110          1.90               2.70              0
# 10           131          5.50              10.90              0
#
#     precip_rate_des  pres_des  uv_des  dewpt_des  rh_des  slp_des  \
# 0             42.56  1,003.50    8.30       3.90      57 1,019.50
# 1             25.00  1,007.50    8.40       6.30      78 1,023.70
# 2             13.19  1,002.80    8.40       9.60      85 1,018.70
# 3             17.38    999.50    8.50       8.50      78 1,015.40
# 4             42.56  1,003.50    8.30       3.90      57 1,019.50
# 5             25.00  1,007.50    8.40       6.30      78 1,023.70
# 6             13.19  1,002.80    8.40       9.60      85 1,018.70
# 7             17.38    999.50    8.50       8.50      78 1,015.40
# 8             42.56  1,003.50    8.30       3.90      57 1,019.50
# 9             13.19  1,002.80    8.40       9.60      85 1,018.70
# 10            17.38    999.50    8.50       8.50      78 1,015.40
#
#    Scheduled departure time Scheduled Arrival Time  Previous Flight Status  \
# 0                   7:59 PM               10:52 PM                    True
# 1                   7:59 PM               10:52 PM                    True
# 2                   7:59 PM               10:52 PM                    True
# 3                   7:59 PM               10:52 PM                    True
# 4                   2:55 PM                4:21 PM                    True
# 5                   2:55 PM                4:21 PM                    True
# 6                   2:55 PM                4:21 PM                    True
# 7                   2:55 PM                4:21 PM                    True
# 8                   1:35 PM                4:25 PM                    True
# 9                   1:35 PM                4:25 PM                    True
# 10                  1:34 PM                4:25 PM                    True
#
#     Scheduled Arrival Hour  Scheduled Arrival Minutes  \
# 0                       22                         52
# 1                       22                         52
# 2                       22                         52
# 3                       22                         52
# 4                       16                         21
# 5                       16                         21
# 6                       16                         21
# 7                       16                         21
# 8                       16                         25
# 9                       16                         25
# 10                      16                         25
#
#     Scheduled departure Hour  Scheduled departure Minutes
# 0                         19                           59
# 1                         19                           59
# 2                         19                           59
# 3                         19                           59
# 4                         14                           55
# 5                         14                           55
# 6                         14                           55
# 7                         14                           55
# 8                         13                           35
# 9                         13                           35
# 10                        13                           34

# %%
combined_df_prev.rename(columns={'Origin': 'Origin Airport'}, inplace=True)

# %%
combined_df_prev.rename(columns={'CarrierCode': 'Carrier Code'}, inplace=True)

# %%
combined_df_prev.rename(columns={'FlightNumber': 'Flight Number'}, inplace=True)

# %%
combined_df_prev.drop(columns=['Date', 'Scheduled departure time', 'Scheduled Arrival Time'], inplace=True)

# %%
subsequent_flights.columns
# Out:
# Index(['Flight Number', 'clouds_des', 'dewpt_des', 'precip_rate_des',
#        'pres_des', 'rh_des', 'slp_des', 'snow_rate_des', 'temp_des', 'uv_des',
#        'wind_dir_des', 'wind_gust_spd_des', 'wind_spd_des', 'Status',
#        'Previous Flight Status', 'Scheduled Arrival Hour',
#        'Scheduled Arrival Minutes', 'Scheduled departure Hour',
#        'Scheduled departure Minutes', 'Date', 'Carrier Code_B6',
#        'Carrier Code_MQ', 'Carrier Code_UA', 'Carrier Code_WN',
#        'Origin Airport_MCO', 'Origin Airport_ORD'],
#       dtype='object')

# %%
combined_df_prev.columns
# Out:
# Index(['Carrier Code', 'Flight Number', 'Origin Airport', 'clouds_des',
#        'temp_des', 'wind_dir_des', 'wind_spd_des', 'wind_gust_spd_des',
#        'snow_rate_des', 'precip_rate_des', 'pres_des', 'uv_des', 'dewpt_des',
#        'rh_des', 'slp_des', 'Previous Flight Status', 'Scheduled Arrival Hour',
#        'Scheduled Arrival Minutes', 'Scheduled departure Hour',
#        'Scheduled departure Minutes'],
#       dtype='object')

# %%
combined_df_prev.head()
# Out:
#   Carrier Code  Flight Number Origin Airport  clouds_des  temp_des  \
# 0           MQ           3402            ORD          84     12.40
# 1           MQ           3402            ORD          49     10.10
# 2           MQ           3402            ORD          90     12.20
# 3           MQ           3402            ORD          72     12.40
# 4           9E           5340            JFK          84     12.40
#
#    wind_dir_des  wind_spd_des  wind_gust_spd_des  snow_rate_des  \
# 0           171          4.20               4.60              0
# 1           227          3.40               6.50              0
# 2           110          1.90               2.70              0
# 3           131          5.50              10.90              0
# 4           171          4.20               4.60              0
#
#    precip_rate_des  pres_des  uv_des  dewpt_des  rh_des  slp_des  \
# 0            42.56  1,003.50    8.30       3.90      57 1,019.50
# 1            25.00  1,007.50    8.40       6.30      78 1,023.70
# 2            13.19  1,002.80    8.40       9.60      85 1,018.70
# 3            17.38    999.50    8.50       8.50      78 1,015.40
# 4            42.56  1,003.50    8.30       3.90      57 1,019.50
#
#    Previous Flight Status  Scheduled Arrival Hour  Scheduled Arrival Minutes  \
# 0                    True                      22                         52
# 1                    True                      22                         52
# 2                    True                      22                         52
# 3                    True                      22                         52
# 4                    True                      16                         21
#
#    Scheduled departure Hour  Scheduled departure Minutes
# 0                        19                           59
# 1                        19                           59
# 2                        19                           59
# 3                        19                           59
# 4                        14                           55

# %%
# L_flight_data_merged_pred = pd.get_dummies(L_flight_data_merged_pred, drop_first = True)

# %%
#here we assume Previous Flight Status to be one value at a time and make predictions
combined_df_prev['Previous Flight Status'] = 1
L_flight_data_merged_pred = combined_df_prev.copy()

combined_df_prev['Previous Flight Status'] = 0
E_flight_data_merged_pred = combined_df_prev.copy()

combined_df_prev['Previous Flight Status'] = 2
O_flight_data_merged_pred = combined_df_prev.copy()

# %%
L_flight_data_merged_pred
# Out:
#    Carrier Code  Flight Number Origin Airport  clouds_des  temp_des  \
# 0            MQ           3402            ORD          84     12.40
# 1            MQ           3402            ORD          49     10.10
# 2            MQ           3402            ORD          90     12.20
# 3            MQ           3402            ORD          72     12.40
# 4            9E           5340            JFK          84     12.40
# 5            9E           5340            JFK          49     10.10
# 6            9E           5340            JFK          90     12.20
# 7            9E           5340            JFK          72     12.40
# 8            B6             56            MCO          84     12.40
# 9            B6             56            MCO          90     12.20
# 10           B6             56            MCO          72     12.40
#
#     wind_dir_des  wind_spd_des  wind_gust_spd_des  snow_rate_des  \
# 0            171          4.20               4.60              0
# 1            227          3.40               6.50              0
# 2            110          1.90               2.70              0
# 3            131          5.50              10.90              0
# 4            171          4.20               4.60              0
# 5            227          3.40               6.50              0
# 6            110          1.90               2.70              0
# 7            131          5.50              10.90              0
# 8            171          4.20               4.60              0
# 9            110          1.90               2.70              0
# 10           131          5.50              10.90              0
#
#     precip_rate_des  pres_des  uv_des  dewpt_des  rh_des  slp_des  \
# 0             42.56  1,003.50    8.30       3.90      57 1,019.50
# 1             25.00  1,007.50    8.40       6.30      78 1,023.70
# 2             13.19  1,002.80    8.40       9.60      85 1,018.70
# 3             17.38    999.50    8.50       8.50      78 1,015.40
# 4             42.56  1,003.50    8.30       3.90      57 1,019.50
# 5             25.00  1,007.50    8.40       6.30      78 1,023.70
# 6             13.19  1,002.80    8.40       9.60      85 1,018.70
# 7             17.38    999.50    8.50       8.50      78 1,015.40
# 8             42.56  1,003.50    8.30       3.90      57 1,019.50
# 9             13.19  1,002.80    8.40       9.60      85 1,018.70
# 10            17.38    999.50    8.50       8.50      78 1,015.40
#
#     Previous Flight Status  Scheduled Arrival Hour  Scheduled Arrival Minutes  \
# 0                        1                      22                         52
# 1                        1                      22                         52
# 2                        1                      22                         52
# 3                        1                      22                         52
# 4                        1                      16                         21
# 5                        1                      16                         21
# 6                        1                      16                         21
# 7                        1                      16                         21
# 8                        1                      16                         25
# 9                        1                      16                         25
# 10                       1                      16                         25
#
#     Scheduled departure Hour  Scheduled departure Minutes
# 0                         19                           59
# 1                         19                           59
# 2                         19                           59
# 3                         19                           59
# 4                         14                           55
# 5                         14                           55
# 6                         14                           55
# 7                         14                           55
# 8                         13                           35
# 9                         13                           35
# 10                        13                           34

# %%
E_flight_data_merged_pred
# Out:
#    Carrier Code  Flight Number Origin Airport  clouds_des  temp_des  \
# 0            MQ           3402            ORD          84     12.40
# 1            MQ           3402            ORD          49     10.10
# 2            MQ           3402            ORD          90     12.20
# 3            MQ           3402            ORD          72     12.40
# 4            9E           5340            JFK          84     12.40
# 5            9E           5340            JFK          49     10.10
# 6            9E           5340            JFK          90     12.20
# 7            9E           5340            JFK          72     12.40
# 8            B6             56            MCO          84     12.40
# 9            B6             56            MCO          90     12.20
# 10           B6             56            MCO          72     12.40
#
#     wind_dir_des  wind_spd_des  wind_gust_spd_des  snow_rate_des  \
# 0            171          4.20               4.60              0
# 1            227          3.40               6.50              0
# 2            110          1.90               2.70              0
# 3            131          5.50              10.90              0
# 4            171          4.20               4.60              0
# 5            227          3.40               6.50              0
# 6            110          1.90               2.70              0
# 7            131          5.50              10.90              0
# 8            171          4.20               4.60              0
# 9            110          1.90               2.70              0
# 10           131          5.50              10.90              0
#
#     precip_rate_des  pres_des  uv_des  dewpt_des  rh_des  slp_des  \
# 0             42.56  1,003.50    8.30       3.90      57 1,019.50
# 1             25.00  1,007.50    8.40       6.30      78 1,023.70
# 2             13.19  1,002.80    8.40       9.60      85 1,018.70
# 3             17.38    999.50    8.50       8.50      78 1,015.40
# 4             42.56  1,003.50    8.30       3.90      57 1,019.50
# 5             25.00  1,007.50    8.40       6.30      78 1,023.70
# 6             13.19  1,002.80    8.40       9.60      85 1,018.70
# 7             17.38    999.50    8.50       8.50      78 1,015.40
# 8             42.56  1,003.50    8.30       3.90      57 1,019.50
# 9             13.19  1,002.80    8.40       9.60      85 1,018.70
# 10            17.38    999.50    8.50       8.50      78 1,015.40
#
#     Previous Flight Status  Scheduled Arrival Hour  Scheduled Arrival Minutes  \
# 0                        0                      22                         52
# 1                        0                      22                         52
# 2                        0                      22                         52
# 3                        0                      22                         52
# 4                        0                      16                         21
# 5                        0                      16                         21
# 6                        0                      16                         21
# 7                        0                      16                         21
# 8                        0                      16                         25
# 9                        0                      16                         25
# 10                       0                      16                         25
#
#     Scheduled departure Hour  Scheduled departure Minutes
# 0                         19                           59
# 1                         19                           59
# 2                         19                           59
# 3                         19                           59
# 4                         14                           55
# 5                         14                           55
# 6                         14                           55
# 7                         14                           55
# 8                         13                           35
# 9                         13                           35
# 10                        13                           34

# %%
O_flight_data_merged_pred
# Out:
#    Carrier Code  Flight Number Origin Airport  clouds_des  temp_des  \
# 0            MQ           3402            ORD          84     12.40
# 1            MQ           3402            ORD          49     10.10
# 2            MQ           3402            ORD          90     12.20
# 3            MQ           3402            ORD          72     12.40
# 4            9E           5340            JFK          84     12.40
# 5            9E           5340            JFK          49     10.10
# 6            9E           5340            JFK          90     12.20
# 7            9E           5340            JFK          72     12.40
# 8            B6             56            MCO          84     12.40
# 9            B6             56            MCO          90     12.20
# 10           B6             56            MCO          72     12.40
#
#     wind_dir_des  wind_spd_des  wind_gust_spd_des  snow_rate_des  \
# 0            171          4.20               4.60              0
# 1            227          3.40               6.50              0
# 2            110          1.90               2.70              0
# 3            131          5.50              10.90              0
# 4            171          4.20               4.60              0
# 5            227          3.40               6.50              0
# 6            110          1.90               2.70              0
# 7            131          5.50              10.90              0
# 8            171          4.20               4.60              0
# 9            110          1.90               2.70              0
# 10           131          5.50              10.90              0
#
#     precip_rate_des  pres_des  uv_des  dewpt_des  rh_des  slp_des  \
# 0             42.56  1,003.50    8.30       3.90      57 1,019.50
# 1             25.00  1,007.50    8.40       6.30      78 1,023.70
# 2             13.19  1,002.80    8.40       9.60      85 1,018.70
# 3             17.38    999.50    8.50       8.50      78 1,015.40
# 4             42.56  1,003.50    8.30       3.90      57 1,019.50
# 5             25.00  1,007.50    8.40       6.30      78 1,023.70
# 6             13.19  1,002.80    8.40       9.60      85 1,018.70
# 7             17.38    999.50    8.50       8.50      78 1,015.40
# 8             42.56  1,003.50    8.30       3.90      57 1,019.50
# 9             13.19  1,002.80    8.40       9.60      85 1,018.70
# 10            17.38    999.50    8.50       8.50      78 1,015.40
#
#     Previous Flight Status  Scheduled Arrival Hour  Scheduled Arrival Minutes  \
# 0                        2                      22                         52
# 1                        2                      22                         52
# 2                        2                      22                         52
# 3                        2                      22                         52
# 4                        2                      16                         21
# 5                        2                      16                         21
# 6                        2                      16                         21
# 7                        2                      16                         21
# 8                        2                      16                         25
# 9                        2                      16                         25
# 10                       2                      16                         25
#
#     Scheduled departure Hour  Scheduled departure Minutes
# 0                         19                           59
# 1                         19                           59
# 2                         19                           59
# 3                         19                           59
# 4                         14                           55
# 5                         14                           55
# 6                         14                           55
# 7                         14                           55
# 8                         13                           35
# 9                         13                           35
# 10                        13                           34

# %%
L_flight_data_merged_pred = pd.get_dummies(L_flight_data_merged_pred, drop_first = True)

# %%
#Ensuring the test dataset has the same dummy columns as the training dataset
missing_cols = set(X_train_sub.columns) - set(L_flight_data_merged_pred.columns)
for c in missing_cols:
    L_flight_data_merged_pred[c] = 0
L_flight_data_merged_pred = L_flight_data_merged_pred[X_train_sub.columns]

# %%
if True: 
    from sklearn.preprocessing import StandardScaler
    sc = StandardScaler()
    L_flight_data_merged_pred = pd.DataFrame(sc.fit_transform(L_flight_data_merged_pred), columns = L_flight_data_merged_pred.columns, index = L_flight_data_merged_pred.index)
L_flight_data_merged_pred
# Out:
#     Flight Number  clouds_des  dewpt_des  precip_rate_des  pres_des  rh_des  \
# 0            0.10        0.55      -1.43             1.54      0.21   -1.57
# 1            0.10       -1.87      -0.37             0.04      1.71    0.35
# 2            0.10        0.97       1.08            -0.96     -0.05    0.99
# 3            0.10       -0.28       0.60            -0.61     -1.29    0.35
# 4            1.03        0.55      -1.43             1.54      0.21   -1.57
# 5            1.03       -1.87      -0.37             0.04      1.71    0.35
# 6            1.03        0.97       1.08            -0.96     -0.05    0.99
# 7            1.03       -0.28       0.60            -0.61     -1.29    0.35
# 8           -1.50        0.55      -1.43             1.54      0.21   -1.57
# 9           -1.50        0.97       1.08            -0.96     -0.05    0.99
# 10          -1.50       -0.28       0.60            -0.61     -1.29    0.35
#
#     slp_des  snow_rate_des  temp_des  uv_des  wind_dir_des  wind_gust_spd_des  \
# 0      0.21           0.00      0.55   -1.35          0.42              -0.49
# 1      1.73           0.00     -2.11    0.00          1.77               0.11
# 2     -0.08           0.00      0.32    0.00         -1.05              -1.09
# 3     -1.28           0.00      0.55    1.35         -0.55               1.50
# 4      0.21           0.00      0.55   -1.35          0.42              -0.49
# 5      1.73           0.00     -2.11    0.00          1.77               0.11
# 6     -0.08           0.00      0.32    0.00         -1.05              -1.09
# 7     -1.28           0.00      0.55    1.35         -0.55               1.50
# 8      0.21           0.00      0.55   -1.35          0.42              -0.49
# 9     -0.08           0.00      0.32    0.00         -1.05              -1.09
# 10    -1.28           0.00      0.55    1.35         -0.55               1.50
#
#     wind_spd_des  Previous Flight Status  Scheduled Arrival Hour  \
# 0           0.31                    0.00                    1.32
# 1          -0.28                    0.00                    1.32
# 2          -1.39                    0.00                    1.32
# 3           1.26                    0.00                    1.32
# 4           0.31                    0.00                   -0.76
# 5          -0.28                    0.00                   -0.76
# 6          -1.39                    0.00                   -0.76
# 7           1.26                    0.00                   -0.76
# 8           0.31                    0.00                   -0.76
# 9          -1.39                    0.00                   -0.76
# 10          1.26                    0.00                   -0.76
#
#     Scheduled Arrival Minutes  Scheduled departure Hour  \
# 0                        1.31                      1.31
# 1                        1.31                      1.31
# 2                        1.31                      1.31
# 3                        1.31                      1.31
# 4                       -0.87                     -0.59
# 5                       -0.87                     -0.59
# 6                       -0.87                     -0.59
# 7                       -0.87                     -0.59
# 8                       -0.59                     -0.96
# 9                       -0.59                     -0.96
# 10                      -0.59                     -0.96
#
#     Scheduled departure Minutes  Carrier Code_B6  Carrier Code_MQ  \
# 0                          0.80            -0.61             1.32
# 1                          0.80            -0.61             1.32
# 2                          0.80            -0.61             1.32
# 3                          0.80            -0.61             1.32
# 4                          0.41            -0.61            -0.76
# 5                          0.41            -0.61            -0.76
# 6                          0.41            -0.61            -0.76
# 7                          0.41            -0.61            -0.76
# 8                         -1.58             1.63            -0.76
# 9                         -1.58             1.63            -0.76
# 10                        -1.68             1.63            -0.76
#
#     Carrier Code_UA  Carrier Code_WN  Origin Airport_MCO  Origin Airport_ORD
# 0              0.00             0.00               -0.61                1.32
# 1              0.00             0.00               -0.61                1.32
# 2              0.00             0.00               -0.61                1.32
# 3              0.00             0.00               -0.61                1.32
# 4              0.00             0.00               -0.61               -0.76
# 5              0.00             0.00               -0.61               -0.76
# 6              0.00             0.00               -0.61               -0.76
# 7              0.00             0.00               -0.61               -0.76
# 8              0.00             0.00                1.63               -0.76
# 9              0.00             0.00                1.63               -0.76
# 10             0.00             0.00                1.63               -0.76

# %%
status_mapping = {0: 'Early', 1: 'Late', 2: 'On-time'}

# %%
# Predict the labels for the test data
y_pred_test_sub_L_flight = rf_2.predict(L_flight_data_merged_pred) 
y_pred_test_sub_L_flight_labels = [status_mapping[pred] for pred in y_pred_test_sub_L_flight]
# Print each label with its corresponding index
for index, label in enumerate(y_pred_test_sub_L_flight_labels):
    print(f"Index {index}: {label}")
# Out:
# Index 0: Late
# Index 1: Late
# Index 2: Late
# Index 3: Late
# Index 4: Early
# Index 5: Early
# Index 6: Early
# Index 7: Early
# Index 8: Early
# Index 9: Late
# Index 10: Late

# %%
E_flight_data_merged_pred = pd.get_dummies(E_flight_data_merged_pred, drop_first = True)

# %%
#Ensuring the test dataset has the same dummy columns as the training dataset
# combined_pred = pd.get_dummies(combined_pred)
missing_cols = set(X_train_sub.columns) - set(E_flight_data_merged_pred.columns)
for c in missing_cols:
    E_flight_data_merged_pred[c] = 0
E_flight_data_merged_pred = E_flight_data_merged_pred[X_train_sub.columns]

# %%
if True: 
    from sklearn.preprocessing import StandardScaler
    sc = StandardScaler()
    E_flight_data_merged_pred = pd.DataFrame(sc.fit_transform(E_flight_data_merged_pred), columns = E_flight_data_merged_pred.columns, index = E_flight_data_merged_pred.index)
E_flight_data_merged_pred
# Out:
#     Flight Number  clouds_des  dewpt_des  precip_rate_des  pres_des  rh_des  \
# 0            0.10        0.55      -1.43             1.54      0.21   -1.57
# 1            0.10       -1.87      -0.37             0.04      1.71    0.35
# 2            0.10        0.97       1.08            -0.96     -0.05    0.99
# 3            0.10       -0.28       0.60            -0.61     -1.29    0.35
# 4            1.03        0.55      -1.43             1.54      0.21   -1.57
# 5            1.03       -1.87      -0.37             0.04      1.71    0.35
# 6            1.03        0.97       1.08            -0.96     -0.05    0.99
# 7            1.03       -0.28       0.60            -0.61     -1.29    0.35
# 8           -1.50        0.55      -1.43             1.54      0.21   -1.57
# 9           -1.50        0.97       1.08            -0.96     -0.05    0.99
# 10          -1.50       -0.28       0.60            -0.61     -1.29    0.35
#
#     slp_des  snow_rate_des  temp_des  uv_des  wind_dir_des  wind_gust_spd_des  \
# 0      0.21           0.00      0.55   -1.35          0.42              -0.49
# 1      1.73           0.00     -2.11    0.00          1.77               0.11
# 2     -0.08           0.00      0.32    0.00         -1.05              -1.09
# 3     -1.28           0.00      0.55    1.35         -0.55               1.50
# 4      0.21           0.00      0.55   -1.35          0.42              -0.49
# 5      1.73           0.00     -2.11    0.00          1.77               0.11
# 6     -0.08           0.00      0.32    0.00         -1.05              -1.09
# 7     -1.28           0.00      0.55    1.35         -0.55               1.50
# 8      0.21           0.00      0.55   -1.35          0.42              -0.49
# 9     -0.08           0.00      0.32    0.00         -1.05              -1.09
# 10    -1.28           0.00      0.55    1.35         -0.55               1.50
#
#     wind_spd_des  Previous Flight Status  Scheduled Arrival Hour  \
# 0           0.31                    0.00                    1.32
# 1          -0.28                    0.00                    1.32
# 2          -1.39                    0.00                    1.32
# 3           1.26                    0.00                    1.32
# 4           0.31                    0.00                   -0.76
# 5          -0.28                    0.00                   -0.76
# 6          -1.39                    0.00                   -0.76
# 7           1.26                    0.00                   -0.76
# 8           0.31                    0.00                   -0.76
# 9          -1.39                    0.00                   -0.76
# 10          1.26                    0.00                   -0.76
#
#     Scheduled Arrival Minutes  Scheduled departure Hour  \
# 0                        1.31                      1.31
# 1                        1.31                      1.31
# 2                        1.31                      1.31
# 3                        1.31                      1.31
# 4                       -0.87                     -0.59
# 5                       -0.87                     -0.59
# 6                       -0.87                     -0.59
# 7                       -0.87                     -0.59
# 8                       -0.59                     -0.96
# 9                       -0.59                     -0.96
# 10                      -0.59                     -0.96
#
#     Scheduled departure Minutes  Carrier Code_B6  Carrier Code_MQ  \
# 0                          0.80            -0.61             1.32
# 1                          0.80            -0.61             1.32
# 2                          0.80            -0.61             1.32
# 3                          0.80            -0.61             1.32
# 4                          0.41            -0.61            -0.76
# 5                          0.41            -0.61            -0.76
# 6                          0.41            -0.61            -0.76
# 7                          0.41            -0.61            -0.76
# 8                         -1.58             1.63            -0.76
# 9                         -1.58             1.63            -0.76
# 10                        -1.68             1.63            -0.76
#
#     Carrier Code_UA  Carrier Code_WN  Origin Airport_MCO  Origin Airport_ORD
# 0              0.00             0.00               -0.61                1.32
# 1              0.00             0.00               -0.61                1.32
# 2              0.00             0.00               -0.61                1.32
# 3              0.00             0.00               -0.61                1.32
# 4              0.00             0.00               -0.61               -0.76
# 5              0.00             0.00               -0.61               -0.76
# 6              0.00             0.00               -0.61               -0.76
# 7              0.00             0.00               -0.61               -0.76
# 8              0.00             0.00                1.63               -0.76
# 9              0.00             0.00                1.63               -0.76
# 10             0.00             0.00                1.63               -0.76

# %%
# Predict the labels for the test data
y_pred_test_sub_E_flight = rf_2.predict(E_flight_data_merged_pred)
y_pred_test_sub_E_flight_labels = [status_mapping[pred] for pred in y_pred_test_sub_E_flight]
# Print each label with its corresponding index
for index, label in enumerate(y_pred_test_sub_E_flight_labels):
    print(f"Index {index}: {label}")
# Out:
# Index 0: Late
# Index 1: Late
# Index 2: Late
# Index 3: Late
# Index 4: Early
# Index 5: Early
# Index 6: Early
# Index 7: Early
# Index 8: Early
# Index 9: Late
# Index 10: Late

# %%
O_flight_data_merged_pred = pd.get_dummies(O_flight_data_merged_pred, drop_first = True)

# %%
#Ensuring the test dataset has the same dummy columns as the training dataset
# combined_pred = pd.get_dummies(combined_pred)
missing_cols = set(X_train_sub.columns) - set(O_flight_data_merged_pred.columns)
for c in missing_cols:
    O_flight_data_merged_pred[c] = 0
O_flight_data_merged_pred = O_flight_data_merged_pred[X_train_sub.columns]

# %%
if True: 
    from sklearn.preprocessing import StandardScaler
    sc = StandardScaler()
    O_flight_data_merged_pred = pd.DataFrame(sc.fit_transform(O_flight_data_merged_pred), columns = O_flight_data_merged_pred.columns, index = O_flight_data_merged_pred.index)
O_flight_data_merged_pred
# Out:
#     Flight Number  clouds_des  dewpt_des  precip_rate_des  pres_des  rh_des  \
# 0            0.10        0.55      -1.43             1.54      0.21   -1.57
# 1            0.10       -1.87      -0.37             0.04      1.71    0.35
# 2            0.10        0.97       1.08            -0.96     -0.05    0.99
# 3            0.10       -0.28       0.60            -0.61     -1.29    0.35
# 4            1.03        0.55      -1.43             1.54      0.21   -1.57
# 5            1.03       -1.87      -0.37             0.04      1.71    0.35
# 6            1.03        0.97       1.08            -0.96     -0.05    0.99
# 7            1.03       -0.28       0.60            -0.61     -1.29    0.35
# 8           -1.50        0.55      -1.43             1.54      0.21   -1.57
# 9           -1.50        0.97       1.08            -0.96     -0.05    0.99
# 10          -1.50       -0.28       0.60            -0.61     -1.29    0.35
#
#     slp_des  snow_rate_des  temp_des  uv_des  wind_dir_des  wind_gust_spd_des  \
# 0      0.21           0.00      0.55   -1.35          0.42              -0.49
# 1      1.73           0.00     -2.11    0.00          1.77               0.11
# 2     -0.08           0.00      0.32    0.00         -1.05              -1.09
# 3     -1.28           0.00      0.55    1.35         -0.55               1.50
# 4      0.21           0.00      0.55   -1.35          0.42              -0.49
# 5      1.73           0.00     -2.11    0.00          1.77               0.11
# 6     -0.08           0.00      0.32    0.00         -1.05              -1.09
# 7     -1.28           0.00      0.55    1.35         -0.55               1.50
# 8      0.21           0.00      0.55   -1.35          0.42              -0.49
# 9     -0.08           0.00      0.32    0.00         -1.05              -1.09
# 10    -1.28           0.00      0.55    1.35         -0.55               1.50
#
#     wind_spd_des  Previous Flight Status  Scheduled Arrival Hour  \
# 0           0.31                    0.00                    1.32
# 1          -0.28                    0.00                    1.32
# 2          -1.39                    0.00                    1.32
# 3           1.26                    0.00                    1.32
# 4           0.31                    0.00                   -0.76
# 5          -0.28                    0.00                   -0.76
# 6          -1.39                    0.00                   -0.76
# 7           1.26                    0.00                   -0.76
# 8           0.31                    0.00                   -0.76
# 9          -1.39                    0.00                   -0.76
# 10          1.26                    0.00                   -0.76
#
#     Scheduled Arrival Minutes  Scheduled departure Hour  \
# 0                        1.31                      1.31
# 1                        1.31                      1.31
# 2                        1.31                      1.31
# 3                        1.31                      1.31
# 4                       -0.87                     -0.59
# 5                       -0.87                     -0.59
# 6                       -0.87                     -0.59
# 7                       -0.87                     -0.59
# 8                       -0.59                     -0.96
# 9                       -0.59                     -0.96
# 10                      -0.59                     -0.96
#
#     Scheduled departure Minutes  Carrier Code_B6  Carrier Code_MQ  \
# 0                          0.80            -0.61             1.32
# 1                          0.80            -0.61             1.32
# 2                          0.80            -0.61             1.32
# 3                          0.80            -0.61             1.32
# 4                          0.41            -0.61            -0.76
# 5                          0.41            -0.61            -0.76
# 6                          0.41            -0.61            -0.76
# 7                          0.41            -0.61            -0.76
# 8                         -1.58             1.63            -0.76
# 9                         -1.58             1.63            -0.76
# 10                        -1.68             1.63            -0.76
#
#     Carrier Code_UA  Carrier Code_WN  Origin Airport_MCO  Origin Airport_ORD
# 0              0.00             0.00               -0.61                1.32
# 1              0.00             0.00               -0.61                1.32
# 2              0.00             0.00               -0.61                1.32
# 3              0.00             0.00               -0.61                1.32
# 4              0.00             0.00               -0.61               -0.76
# 5              0.00             0.00               -0.61               -0.76
# 6              0.00             0.00               -0.61               -0.76
# 7              0.00             0.00               -0.61               -0.76
# 8              0.00             0.00                1.63               -0.76
# 9              0.00             0.00                1.63               -0.76
# 10             0.00             0.00                1.63               -0.76

# %%
# Predict the labels for the test data
y_pred_test_sub_O_flight = rf_2.predict(O_flight_data_merged_pred) 
y_pred_test_sub_O_flight_labels = [status_mapping[pred] for pred in y_pred_test_sub_O_flight]
# Print each label with its corresponding index
for index, label in enumerate(y_pred_test_sub_O_flight_labels):
    print(f"Index {index}: {label}")
# Out:
# Index 0: Late
# Index 1: Late
# Index 2: Late
# Index 3: Late
# Index 4: Early
# Index 5: Early
# Index 6: Early
# Index 7: Early
# Index 8: Early
# Index 9: Late
# Index 10: Late
